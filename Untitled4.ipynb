# %%
import pandas as pd
import scanpy as sp

# %%
labels=pd.read_csv("./data/g8_query_emb.csv",index_col=0)

# %%
adata=sp.read_h5ad("./data/combined_g8.h5ad")

# %%
# Out:
# ['Macrophages',
#  'T cell lineage',
#  'Monocytes',
#  'Unknown',
#  'Fibroblasts',
#  'Basal',
#  'B cell lineage',
#  'Innate lymphoid cell NK',
#  'Multiciliated lineage',
#  'Dendritic cells',
#  'AT2',
#  'Secretory',
#  'Mast cells',
#  'EC capillary',
#  'EC venous',
#  'Lymphatic EC mature',
#  'AT1',
#  'Myofibroblasts',
#  'None',
#  'EC arterial',
#  'Submucosal Secretory',
#  'Lymphatic EC differentiating',
#  'Rare',
#  'SM activated stress response']

# %%
labels
# Out:
#                      ann_level_1_pred  ann_level_1_uncertainty  \
# AAACCCAAGATGGCGT-1_1           Immune             0.000000e+00
# AAACCCAGTGGCCACT-1_1           Immune             0.000000e+00
# AAACCCATCACATCAG-1_1           Immune             0.000000e+00
# AAACGAACAGTGACCC-1_1       Epithelial             5.960464e-08
# AAACGAACATTGACCA-1_1           Immune             5.960464e-08
# ...                               ...                      ...
# TTTGTTGCAACACGAG-1_8       Epithelial             5.960464e-08
# TTTGTTGCATCGGAGA-1_8       Epithelial             5.960464e-08
# TTTGTTGGTATGCTAC-1_8       Epithelial             0.000000e+00
# TTTGTTGGTGGTTCTA-1_8       Epithelial             1.192093e-07
# TTTGTTGGTTTCGACA-1_8           Stroma             5.960464e-08
#
#                         ann_level_2_pred  ann_level_2_uncertainty  \
# AAACCCAAGATGGCGT-1_1             Myeloid             0.000000e+00
# AAACCCAGTGGCCACT-1_1             Myeloid             0.000000e+00
# ...

# %%
labels['ann_level_3_pred']
# Out:
# AAACCCAAGATGGCGT-1_1    Macrophages
# AAACCCAGTGGCCACT-1_1      Monocytes
# AAACCCATCACATCAG-1_1        Unknown
# AAACGAACAGTGACCC-1_1      Secretory
# AAACGAACATTGACCA-1_1        Unknown
#                            ...
# TTTGTTGCAACACGAG-1_8          Basal
# TTTGTTGCATCGGAGA-1_8          Basal
# TTTGTTGGTATGCTAC-1_8          Basal
# TTTGTTGGTGGTTCTA-1_8          Basal
# TTTGTTGGTTTCGACA-1_8        Unknown
# Name: ann_level_3_pred, Length: 46009, dtype: object

# %%
adata.obs['cell_type_seurat']
# Out:
# AAACCCAAGATGGCGT-1_1                        0
# AAACCCAGTGGCCACT-1_1                        3
# AAACCCATCACATCAG-1_1                        3
# AAACGAACAGTGACCC-1_1         Epithelial cells
# AAACGAACATTGACCA-1_1                        1
#                                 ...
# TTTGTTGCAACACGAG-1_8         Epithelial cells
# TTTGTTGCATCGGAGA-1_8         Epithelial cells
# TTTGTTGGTATGCTAC-1_8         Epithelial cells
# TTTGTTGGTGGTTCTA-1_8         Epithelial cells
# TTTGTTGGTTTCGACA-1_8    Fibroblasts-Pericytes
# Name: cell_type_seurat, Length: 46009, dtype: category
# Categories (14, object): ['0', '1', '2', '3', ..., '10', 'Pericytes', '14', 'Endothelial cells']
