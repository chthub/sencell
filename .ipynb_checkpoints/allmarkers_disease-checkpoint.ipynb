# %%
import numpy as np
import seaborn as sns
import torch

import umap
import matplotlib.pyplot as plt
import pandas as pd
from community import community_louvain
from torch_geometric.utils import k_hop_subgraph,to_networkx,from_networkx
import matplotlib

import utils
import plots
from model_AE import reduction_AE
from model_GAT import Encoder,SenGAE,train_GAT
from model_Sencell import Sencell

import logging
import os
import argparse


parser = argparse.ArgumentParser(description='Main program for sencells')

parser.add_argument('--output_dir', type=str, default='./outputs', help='')
parser.add_argument('--exp_name', type=str, default='', help='')

args = parser.parse_args(args=[])

args.exp_name='disease'

if not os.path.exists(args.output_dir):
    os.makedirs(args.output_dir)

logging.basicConfig(format='%(asctime)s.%(msecs)03d [%(levelname)s] [%(filename)s:%(lineno)d] %(message)s',
                    datefmt='# %Y-%m-%d %H:%M:%S')

logging.getLogger().setLevel(logging.DEBUG)
logger = logging.getLogger()

# Part 1: load and process data
# cell_cluster_arr在画umap的时候用
adata,cluster_cell_ls,cell_cluster_arr,celltype_names=utils.load_data_disease()
# plots.umapPlot(adata.obsm['X_umap'],clusters=cell_cluster_arr,labels=celltype_names)

new_data,markers_index,\
sen_gene_ls,nonsen_gene_ls,gene_names=utils.process_data(adata,cluster_cell_ls,cell_cluster_arr)

print(f'cell num: {new_data.shape[0]}, gene num: {new_data.shape[1]}')

gene_cell=new_data.X.toarray().T
graph_nx=utils.build_graph_nx(gene_cell,cell_cluster_arr,sen_gene_ls,nonsen_gene_ls,gene_names)
logger.info("Part 1, data loading and processing end!")

# Part 2: generate init embedding
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device:',device)
args.device=device

retrain=True
if retrain:
    gene_embed,cell_embed=reduction_AE(gene_cell,device)
    print(gene_embed.shape,cell_embed.shape)
    torch.save(gene_embed,os.path.join(args.output_dir,f'{args.exp_name}_gene.emb'))
    torch.save(cell_embed,os.path.join(args.output_dir,f'{args.exp_name}_cell.emb'))
else:
    gene_embed=torch.load(os.path.join(args.output_dir,f'{args.exp_name}_gene.emb'))
    cell_embed=torch.load(os.path.join(args.output_dir,f'{args.exp_name}_cell.emb'))

graph_nx=utils.add_nx_embedding(graph_nx,gene_embed,cell_embed)
graph_pyg=utils.build_graph_pyg(gene_cell,gene_embed,cell_embed)
logger.info("Part 2, AE end!")

# Part 3: train GAT
# graph_pyg=graph_pyg.to('cpu')
args.gene_num=gene_cell.shape[0]
args.cell_num=gene_cell.shape[1]



GAT_model=train_GAT(graph_nx,graph_pyg,args,retrain=True,resampling=True)
logger.info("Part 3, training GAT end!")



from sampling import identify_sencell_marker_graph
from sampling import sub_sampling_by_random
from model_Sencell import cell_optim,update_cell_embeddings,old_cell_optim

from sampling import identify_sengene_then_sencell


all_gene_ls=[]

list_sencell_cover=[]
list_sengene_cover=[]

def get_sencell_cover(old_sencell_dict,sencell_dict):
    set1=set(list(old_sencell_dict.keys()))
    set2=set(list(sencell_dict.keys()))
    set3=set1.intersection(set2)
    print('sencell cover:',len(set3)/len(set2))
    
    return len(set3)/len(set2)

def get_sengene_cover(old_sengene_ls,sengene_ls):
    set1=set(old_sengene_ls)
    set2=set(sengene_ls)
    set3=set1.intersection(set2)
    print('sengene cover:',len(set3)/len(set2))
    
    return len(set3)/len(set2)
# Out:
# # 2022-11-30 14:16:13.975 [DEBUG] [attrs.py:77] Creating converter from 3 to 5
# cluster 数量： 14
# celltype names: ['0', '1', '2', '3', '5', 'Epithelial cells', '7', '8', '10', 'Pericytes', 'Fibroblasts-Pericytes', '14', '9', 'Endothelial cells']
# ---------------------  -----
# 0                      10712
# 1                       7273
# 2                       5435
# 3                       3923
# 5                       2695
# Epithelial cells        2385
# 7                       1630
# 8                       1607
# 10                       900
# Pericytes                571
# Fibroblasts-Pericytes    466
# 14                       361
# 9                        263
# Endothelial cells        186
# ---------------------  -----
# 各marker list所包含的gene数：
#   Markers1    Markers2    Markers3    Markers4
# ----------  ----------  ----------  ----------
#        126          78         145          84
# total marker genes:  380
# /users/PCON0022/haocheng/.conda/envs/deepmaps_env/lib/python3.8/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# highly_genes num:  2000
# After highly genes dropped duplicate:  1924
# Total gene num: 2286
# cell num: 38407, gene num: 2286
# The number of edges: 3688551
# # 2022-11-30 14:16:35.860 [INFO] [4270138861.py:53] Part 1, data loading and processing end!
# device: cuda:0
# Epoch : 1999 | train_loss:0.040717933327
# Epoch : 1999 | train_loss:0.073554396629
# torch.Size([2286, 128]) torch.Size([38407, 128])
# the number of edges: 3688551
# edge index:  torch.Size([2, 3688551])
# node feature:  torch.Size([40693, 128])
# Pyg graph: Data(x=[40693, 128], edge_index=[2, 7377102], y=[40693])
# # 2022-11-30 14:23:17.302 [INFO] [4270138861.py:72] Part 2, AE end!
# graph.is_directed(): False
# Start sampling ...
# 100%|██████████| 50/50 [07:52<00:00,  9.46s/it]
# sampling end, time:  472.9620280265808
# Epoch:  0
# subgraph loss:  34.307864379882815
# subgraph loss:  34.356353759765625
# subgraph loss:  34.48566665649414
# subgraph loss:  34.2494400024414
# subgraph loss:  34.33081817626953
# subgraph loss:  34.309766387939455
# subgraph loss:  34.39461669921875
# subgraph loss:  34.333100128173825
# subgraph loss:  34.39757461547852
# subgraph loss:  34.42898406982422
# subgraph loss:  34.33153076171875
# subgraph loss:  34.425802612304686
# subgraph loss:  34.372962188720706
# subgraph loss:  34.33596496582031
# subgraph loss:  34.355980682373044
# subgraph loss:  34.35541687011719
# subgraph loss:  34.32461776733398
# subgraph loss:  34.357496643066405
# subgraph loss:  34.18871154785156
# subgraph loss:  34.331060791015624
# subgraph loss:  34.35059127807617
# subgraph loss:  34.375727844238284
# subgraph loss:  34.31633758544922
# subgraph loss:  34.213270568847655
# subgraph loss:  34.37082443237305
# subgraph loss:  34.32482757568359
# subgraph loss:  34.30204391479492
# subgraph loss:  34.311589050292966
# subgraph loss:  34.17705383300781
# subgraph loss:  34.05341110229492
# subgraph loss:  34.04014663696289
# subgraph loss:  33.754225158691405
# subgraph loss:  34.03266220092773
# subgraph loss:  33.64149551391601
# subgraph loss:  33.821006774902344
# subgraph loss:  33.96389389038086
# subgraph loss:  33.55367431640625
# subgraph loss:  33.369719696044925
# subgraph loss:  33.94648818969726
# subgraph loss:  34.993830871582034
# subgraph loss:  34.184069061279295
# subgraph loss:  34.23225402832031
# subgraph loss:  34.268914794921876
# subgraph loss:  34.2848876953125
# subgraph loss:  34.307655334472656
# subgraph loss:  34.19874649047851
# subgraph loss:  34.20845489501953
# subgraph loss:  34.19376678466797
# subgraph loss:  34.1143798828125
# subgraph loss:  34.285729217529294
# EPOCH loss 34.223308166503905
# Epoch:  1
# subgraph loss:  34.1710205078125
# subgraph loss:  33.999176788330075
# subgraph loss:  33.44298400878906
# subgraph loss:  31.403714752197267
# subgraph loss:  29.817209243774414
# subgraph loss:  29.018685150146485
# subgraph loss:  28.80601806640625
# subgraph loss:  27.86563034057617
# subgraph loss:  28.96720314025879
# subgraph loss:  27.434942626953124
# subgraph loss:  27.742907333374024
# subgraph loss:  27.866766357421874
# subgraph loss:  27.441482162475587
# subgraph loss:  27.352488327026368
# subgraph loss:  26.743976974487303
# subgraph loss:  26.692747497558592
# subgraph loss:  21.21475601196289
# subgraph loss:  10.834395217895509
# subgraph loss:  6.276312255859375
# subgraph loss:  4.446488094329834
# subgraph loss:  3.4171597480773928
# subgraph loss:  3.025638723373413
# subgraph loss:  2.550015592575073
# subgraph loss:  2.3455568313598634
# subgraph loss:  2.2290857315063475
# subgraph loss:  2.142024040222168
# subgraph loss:  2.050219774246216
# subgraph loss:  2.0173776626586912
# subgraph loss:  2.0229188919067385
# subgraph loss:  1.967908501625061
# subgraph loss:  1.9733851671218872
# subgraph loss:  1.9501789569854737
# subgraph loss:  1.9241717338562012
# subgraph loss:  1.952042245864868
# subgraph loss:  1.9062071561813354
# subgraph loss:  1.9000121116638184
# subgraph loss:  1.9267011404037475
# subgraph loss:  1.866139554977417
# subgraph loss:  1.858246421813965
# subgraph loss:  1.8803472995758057
# subgraph loss:  1.8844744443893433
# subgraph loss:  1.8808223247528075
# subgraph loss:  1.8593077659606934
# subgraph loss:  1.8825931072235107
# subgraph loss:  1.8456929683685304
# subgraph loss:  1.834395170211792
# subgraph loss:  1.8777054786682128
# subgraph loss:  1.825717306137085
# subgraph loss:  1.8081887722015382
# subgraph loss:  1.806600284576416
# EPOCH loss 11.458994795322418
# Epoch:  2
# subgraph loss:  1.81933913230896
# subgraph loss:  1.8331947326660156
# subgraph loss:  1.848355221748352
# subgraph loss:  1.8094196319580078
# subgraph loss:  1.7895853757858275
# subgraph loss:  1.8140530109405517
# subgraph loss:  1.8016412496566772
# subgraph loss:  1.8270030975341798
# subgraph loss:  1.808269238471985
# subgraph loss:  1.8114619731903077
# subgraph loss:  1.7974384546279907
# subgraph loss:  1.8135069847106933
# subgraph loss:  1.7842421293258668
# subgraph loss:  1.76725914478302
# subgraph loss:  1.7823330879211425
# subgraph loss:  1.8057414293289185
# subgraph loss:  1.7750420808792113
# subgraph loss:  1.8033764839172364
# subgraph loss:  1.782392406463623
# subgraph loss:  1.7788609266281128
# subgraph loss:  1.76708927154541
# subgraph loss:  1.795292115211487
# subgraph loss:  1.804731845855713
# subgraph loss:  1.7818004369735718
# subgraph loss:  1.7781954526901245
# subgraph loss:  1.7690902471542358
# subgraph loss:  1.7465149402618407
# subgraph loss:  1.7327851057052612
# subgraph loss:  1.7843461275100707
# subgraph loss:  1.7828919887542725
# subgraph loss:  1.7803071022033692
# subgraph loss:  1.7918449640274048
# subgraph loss:  1.7294473886489867
# subgraph loss:  1.7834133863449098
# subgraph loss:  1.7429916143417359
# subgraph loss:  1.7584803819656372
# subgraph loss:  1.7852944135665894
# subgraph loss:  1.698223853111267
# subgraph loss:  1.7410943031311035
# subgraph loss:  1.7629830598831178
# subgraph loss:  1.755437397956848
# subgraph loss:  1.7491514682769775
# subgraph loss:  1.762129044532776
# subgraph loss:  1.775582242012024
# subgraph loss:  1.7388941287994384
# subgraph loss:  1.7438542127609253
# subgraph loss:  1.7626352548599242
# subgraph loss:  1.7164201498031617
# subgraph loss:  1.7270795345306396
# subgraph loss:  1.7389766216278075
# EPOCH loss 1.7767898769378667
# Epoch:  3
# subgraph loss:  1.7389774322509766
# subgraph loss:  1.7402289628982544
# subgraph loss:  1.753170895576477
# subgraph loss:  1.7333970546722413
# subgraph loss:  1.7031171798706055
# subgraph loss:  1.7408879756927491
# subgraph loss:  1.735619306564331
# subgraph loss:  1.7543331861495972
# subgraph loss:  1.7552865743637085
# subgraph loss:  1.7432555675506591
# subgraph loss:  1.7370685815811158
# subgraph loss:  1.7324218511581422
# subgraph loss:  1.7180579900741577
# subgraph loss:  1.683485460281372
# subgraph loss:  1.6974814414978028
# subgraph loss:  1.729907751083374
# subgraph loss:  1.7151015758514405
# subgraph loss:  1.7619523286819458
# subgraph loss:  1.7291682481765747
# subgraph loss:  1.72915518283844
# subgraph loss:  1.7207491397857666
# subgraph loss:  1.7302509069442749
# subgraph loss:  1.7338164806365968
# subgraph loss:  1.7248737335205078
# subgraph loss:  1.716262650489807
# subgraph loss:  1.7357887506484986
# subgraph loss:  1.6965964794158936
# subgraph loss:  1.688658022880554
# subgraph loss:  1.721480703353882
# subgraph loss:  1.736204195022583
# subgraph loss:  1.7173147439956664
# subgraph loss:  1.743879222869873
# subgraph loss:  1.679931139945984
# subgraph loss:  1.7418836593627929
# subgraph loss:  1.6897720575332642
# subgraph loss:  1.6998512029647828
# subgraph loss:  1.7154850244522095
# subgraph loss:  1.6544248342514039
# subgraph loss:  1.7188931465148927
# subgraph loss:  1.7083388328552247
# subgraph loss:  1.7237266778945923
# subgraph loss:  1.6994309186935426
# subgraph loss:  1.7134806871414185
# subgraph loss:  1.7198526859283447
# subgraph loss:  1.6912394762039185
# subgraph loss:  1.6736939430236817
# subgraph loss:  1.7053394317626953
# subgraph loss:  1.6685044765472412
# subgraph loss:  1.6612396001815797
# subgraph loss:  1.6572988033294678
# EPOCH loss 1.7164067234992981
# Epoch:  4
# subgraph loss:  1.6705228805541992
# subgraph loss:  1.672777271270752
# subgraph loss:  1.6838563680648804
# subgraph loss:  1.6392983675003052
# subgraph loss:  1.6248239517211913
# subgraph loss:  1.6501333951950072
# subgraph loss:  1.621676993370056
# subgraph loss:  1.6150477647781372
# subgraph loss:  1.621347427368164
# subgraph loss:  1.5872828006744384
# subgraph loss:  1.5459604024887086
# subgraph loss:  1.5811469078063964
# subgraph loss:  1.5187011003494262
# subgraph loss:  1.4997653245925904
# subgraph loss:  1.4872009992599486
# subgraph loss:  1.4943434476852417
# subgraph loss:  1.4622243404388429
# subgraph loss:  1.490507674217224
# subgraph loss:  1.4344039678573608
# subgraph loss:  1.4479891777038574
# subgraph loss:  1.4417309522628785
# subgraph loss:  1.4365279912948608
# subgraph loss:  1.436892294883728
# subgraph loss:  1.4369927883148192
# subgraph loss:  1.4219316482543944
# subgraph loss:  1.4161095857620238
# subgraph loss:  1.3894980669021606
# subgraph loss:  1.3929187774658203
# subgraph loss:  1.4105216264724731
# subgraph loss:  1.4053926944732666
# subgraph loss:  1.4002244234085084
# subgraph loss:  1.378463363647461
# subgraph loss:  1.367323350906372
# subgraph loss:  1.3905138731002809
# subgraph loss:  1.382067608833313
# subgraph loss:  1.373087430000305
# subgraph loss:  1.3879197835922241
# subgraph loss:  1.338252353668213
# subgraph loss:  1.3627898693084717
# subgraph loss:  1.373057985305786
# subgraph loss:  1.3546236515045167
# subgraph loss:  1.3365100383758546
# subgraph loss:  1.3598469257354737
# subgraph loss:  1.355629801750183
# subgraph loss:  1.3388076782226563
# subgraph loss:  1.3266125917434692
# subgraph loss:  1.340764594078064
# subgraph loss:  1.3253390789031982
# subgraph loss:  1.310771608352661
# subgraph loss:  1.3291292905807495
# EPOCH loss 1.4533852458000185
# Epoch:  5
# subgraph loss:  1.3264060497283936
# subgraph loss:  1.3305948734283448
# subgraph loss:  1.3362071990966797
# subgraph loss:  1.3249119758605956
# subgraph loss:  1.2857951164245605
# subgraph loss:  1.3212431430816651
# subgraph loss:  1.312535810470581
# subgraph loss:  1.3244885206222534
# subgraph loss:  1.3229169130325318
# subgraph loss:  1.3370936155319213
# subgraph loss:  1.3253608226776123
# subgraph loss:  1.2946275234222413
# subgraph loss:  1.3021989107131957
# subgraph loss:  1.2868226528167725
# subgraph loss:  1.2965157508850098
# subgraph loss:  1.2983950614929198
# subgraph loss:  1.2783907890319823
# subgraph loss:  1.3180161476135255
# subgraph loss:  1.2938506603240967
# subgraph loss:  1.3030723094940186
# subgraph loss:  1.2881255149841309
# subgraph loss:  1.2933860063552856
# subgraph loss:  1.294783639907837
# subgraph loss:  1.2905974864959717
# subgraph loss:  1.2980042457580567
# subgraph loss:  1.3067718505859376
# subgraph loss:  1.2706477165222168
# subgraph loss:  1.2769776582717896
# subgraph loss:  1.2894683122634887
# subgraph loss:  1.2849363803863525
# subgraph loss:  1.2800505876541137
# subgraph loss:  1.2974148988723755
# subgraph loss:  1.2591768980026246
# subgraph loss:  1.2938842058181763
# subgraph loss:  1.2736080408096313
# subgraph loss:  1.2872918605804444
# subgraph loss:  1.2879850625991822
# subgraph loss:  1.252625870704651
# subgraph loss:  1.2724351167678833
# subgraph loss:  1.2780726194381713
# subgraph loss:  1.286281418800354
# subgraph loss:  1.270300316810608
# subgraph loss:  1.2777304887771606
# subgraph loss:  1.286528182029724
# subgraph loss:  1.2683461904525757
# subgraph loss:  1.2652958869934081
# subgraph loss:  1.2687254428863526
# subgraph loss:  1.247359299659729
# subgraph loss:  1.2514312744140625
# subgraph loss:  1.2659657955169679
# EPOCH loss 1.2916730422973632
# Epoch:  6
# subgraph loss:  1.2612340688705443
# subgraph loss:  1.2636842727661133
# subgraph loss:  1.276124858856201
# subgraph loss:  1.2620129108428955
# subgraph loss:  1.2375702619552613
# subgraph loss:  1.2577079772949218
# subgraph loss:  1.2563548326492309
# subgraph loss:  1.2638060092926025
# subgraph loss:  1.2582496404647827
# subgraph loss:  1.2526256322860718
# subgraph loss:  1.2467725276947021
# subgraph loss:  1.236927056312561
# subgraph loss:  1.2471566915512085
# subgraph loss:  1.241954755783081
# subgraph loss:  1.2404151678085327
# subgraph loss:  1.244009256362915
# subgraph loss:  1.2384451150894165
# subgraph loss:  1.2629119634628296
# subgraph loss:  1.2407062768936157
# subgraph loss:  1.2530725240707397
# subgraph loss:  1.2391121625900268
# subgraph loss:  1.240563988685608
# subgraph loss:  1.2366909742355348
# subgraph loss:  1.2382517337799073
# subgraph loss:  1.2400985717773438
# subgraph loss:  1.2492392778396606
# subgraph loss:  1.2268182516098023
# subgraph loss:  1.2186919689178466
# subgraph loss:  1.243538236618042
# subgraph loss:  1.2298805236816406
# subgraph loss:  1.225568675994873
# subgraph loss:  1.24561607837677
# subgraph loss:  1.2067020416259766
# subgraph loss:  1.2378869771957397
# subgraph loss:  1.2183999061584472
# subgraph loss:  1.2256881237030028
# subgraph loss:  1.2365978717803956
# subgraph loss:  1.1998413324356079
# subgraph loss:  1.2208500146865844
# subgraph loss:  1.2285671710968018
# subgraph loss:  1.240317416191101
# subgraph loss:  1.218223261833191
# subgraph loss:  1.2350830793380738
# subgraph loss:  1.2344254016876222
# subgraph loss:  1.2149339199066163
# subgraph loss:  1.210448932647705
# subgraph loss:  1.2177299976348877
# subgraph loss:  1.1987331628799438
# subgraph loss:  1.21121187210083
# subgraph loss:  1.2190720081329345
# EPOCH loss 1.2370104947090148
# Epoch:  7
# subgraph loss:  1.2120898008346557
# subgraph loss:  1.2273462295532227
# subgraph loss:  1.2134586334228517
# subgraph loss:  1.2089330673217773
# subgraph loss:  1.171433401107788
# subgraph loss:  1.217974019050598
# subgraph loss:  1.2068222522735597
# subgraph loss:  1.2111207962036132
# subgraph loss:  1.2053159952163697
# subgraph loss:  1.2059781312942506
# subgraph loss:  1.1946247577667237
# subgraph loss:  1.1732696056365968
# subgraph loss:  1.1977369785308838
# subgraph loss:  1.1859217166900635
# subgraph loss:  1.1824779033660888
# subgraph loss:  1.1835246324539184
# subgraph loss:  1.1610979080200194
# subgraph loss:  1.190194296836853
# subgraph loss:  1.1743349075317382
# subgraph loss:  1.1933834552764893
# subgraph loss:  1.165679407119751
# subgraph loss:  1.172304368019104
# subgraph loss:  1.1636227369308472
# subgraph loss:  1.1740781784057617
# subgraph loss:  1.1675230264663696
# subgraph loss:  1.1679260730743408
# subgraph loss:  1.1536584377288819
# subgraph loss:  1.140646767616272
# subgraph loss:  1.1597830057144165
# subgraph loss:  1.1522200584411622
# subgraph loss:  1.1391183614730835
# subgraph loss:  1.1820050001144409
# subgraph loss:  1.1236691236495973
# subgraph loss:  1.1499748468399047
# subgraph loss:  1.1441892862319947
# subgraph loss:  1.1506309509277344
# subgraph loss:  1.1633994817733764
# subgraph loss:  1.1216335535049438
# subgraph loss:  1.1488289833068848
# subgraph loss:  1.1556856393814088
# subgraph loss:  1.154924988746643
# subgraph loss:  1.1385651588439942
# subgraph loss:  1.16177396774292
# subgraph loss:  1.1615696191787719
# subgraph loss:  1.1446443319320678
# subgraph loss:  1.136112141609192
# subgraph loss:  1.136347770690918
# subgraph loss:  1.1325770139694213
# subgraph loss:  1.1435031175613404
# subgraph loss:  1.1406758785247804
# EPOCH loss 1.1692861952781677
# Epoch:  8
# subgraph loss:  1.1377135038375854
# subgraph loss:  1.1571956396102905
# subgraph loss:  1.1437541484832763
# subgraph loss:  1.140241312980652
# subgraph loss:  1.0973671913146972
# subgraph loss:  1.130527138710022
# subgraph loss:  1.1165361166000367
# subgraph loss:  1.1279569149017334
# subgraph loss:  1.130824899673462
# subgraph loss:  1.1325283765792846
# subgraph loss:  1.1159055471420287
# subgraph loss:  1.10457284450531
# subgraph loss:  1.1271912813186646
# subgraph loss:  1.1166746854782104
# subgraph loss:  1.107526683807373
# subgraph loss:  1.1212559700012208
# subgraph loss:  1.0995813131332397
# subgraph loss:  1.1289762258529663
# subgraph loss:  1.1406134128570558
# subgraph loss:  1.1698251485824585
# subgraph loss:  1.1224918127059937
# subgraph loss:  1.13616144657135
# subgraph loss:  1.1255059480667113
# subgraph loss:  1.1362442255020142
# subgraph loss:  1.1310628175735473
# subgraph loss:  1.1145140171051025
# subgraph loss:  1.1016888618469238
# subgraph loss:  1.091281270980835
# subgraph loss:  1.1151037216186523
# subgraph loss:  1.1105640888214112
# subgraph loss:  1.1005191564559937
# subgraph loss:  1.1237392187118531
# subgraph loss:  1.0901845693588257
# subgraph loss:  1.1196941614151001
# subgraph loss:  1.1082793474197388
# subgraph loss:  1.110253357887268
# subgraph loss:  1.128217101097107
# subgraph loss:  1.0939578771591187
# subgraph loss:  1.1130100965499878
# subgraph loss:  1.1170900821685792
# subgraph loss:  1.1218392610549928
# subgraph loss:  1.105474042892456
# subgraph loss:  1.1116780996322633
# subgraph loss:  1.1247207403182984
# subgraph loss:  1.109774661064148
# subgraph loss:  1.1050464868545533
# subgraph loss:  1.1064863443374633
# subgraph loss:  1.0984588384628295
# subgraph loss:  1.109444499015808
# subgraph loss:  1.1096916437149047
# EPOCH loss 1.1187789230346679
# Epoch:  9
# subgraph loss:  1.1120208263397218
# subgraph loss:  1.1254828453063965
# subgraph loss:  1.1160282135009765
# subgraph loss:  1.1098227739334106
# subgraph loss:  1.07118878364563
# subgraph loss:  1.1070938110351562
# subgraph loss:  1.097220778465271
# subgraph loss:  1.1026342153549193
# subgraph loss:  1.1011107683181762
# subgraph loss:  1.104227328300476
# subgraph loss:  1.0917129278182984
# subgraph loss:  1.0751004934310913
# subgraph loss:  1.1070281505584716
# subgraph loss:  1.091644024848938
# subgraph loss:  1.0939806938171386
# subgraph loss:  1.1008066415786744
# subgraph loss:  1.0808791875839234
# subgraph loss:  1.1055509567260742
# subgraph loss:  1.0933452606201173
# subgraph loss:  1.1167636394500733
# subgraph loss:  1.088701605796814
# subgraph loss:  1.0985451221466065
# subgraph loss:  1.0918460845947267
# subgraph loss:  1.1069285869598389
# subgraph loss:  1.099402618408203
# subgraph loss:  1.1061376094818116
# subgraph loss:  1.0928312301635743
# subgraph loss:  1.0770437240600585
# subgraph loss:  1.097299337387085
# subgraph loss:  1.099859929084778
# subgraph loss:  1.0882968187332154
# subgraph loss:  1.1055302143096923
# subgraph loss:  1.0727711915969849
# subgraph loss:  1.1004894018173217
# subgraph loss:  1.1143057346343994
# subgraph loss:  1.133693814277649
# subgraph loss:  1.1321044445037842
# subgraph loss:  1.0862814903259277
# subgraph loss:  1.1065406799316406
# subgraph loss:  1.1180493593215943
# subgraph loss:  1.109759759902954
# subgraph loss:  1.0956701755523681
# subgraph loss:  1.103980302810669
# subgraph loss:  1.1121282577514648
# subgraph loss:  1.0912884712219237
# subgraph loss:  1.0898562908172607
# subgraph loss:  1.091903805732727
# subgraph loss:  1.0840790748596192
# subgraph loss:  1.0886922836303712
# subgraph loss:  1.0918366670608521
# EPOCH loss 1.099589928150177
# Epoch:  10
# subgraph loss:  1.0937447547912598
# subgraph loss:  1.1074900150299072
# subgraph loss:  1.1040755987167359
# subgraph loss:  1.1025059223175049
# subgraph loss:  1.0657968282699586
# subgraph loss:  1.0934928894042968
# subgraph loss:  1.089971375465393
# subgraph loss:  1.0860682725906372
# subgraph loss:  1.082436752319336
# subgraph loss:  1.0874534368515014
# subgraph loss:  1.0783947467803956
# subgraph loss:  1.0606953620910644
# subgraph loss:  1.0942245721817017
# subgraph loss:  1.074522614479065
# subgraph loss:  1.0802560806274415
# subgraph loss:  1.086946153640747
# subgraph loss:  1.0634583950042724
# subgraph loss:  1.087802815437317
# subgraph loss:  1.079710102081299
# subgraph loss:  1.0995473623275758
# subgraph loss:  1.0738199710845948
# subgraph loss:  1.080360770225525
# subgraph loss:  1.0845531940460205
# subgraph loss:  1.0933038473129273
# subgraph loss:  1.0902402877807618
# subgraph loss:  1.0811505794525147
# subgraph loss:  1.0729125261306762
# subgraph loss:  1.0623984813690186
# subgraph loss:  1.0803990602493285
# subgraph loss:  1.0840596199035644
# subgraph loss:  1.0682229280471802
# subgraph loss:  1.10031099319458
# subgraph loss:  1.0659487009048463
# subgraph loss:  1.08872492313385
# subgraph loss:  1.0775184392929078
# subgraph loss:  1.0830524206161498
# subgraph loss:  1.096266269683838
# subgraph loss:  1.0635242223739625
# subgraph loss:  1.08534095287323
# subgraph loss:  1.0857312440872193
# subgraph loss:  1.093045449256897
# subgraph loss:  1.0828843355178832
# subgraph loss:  1.0875370502471924
# subgraph loss:  1.1051945447921754
# subgraph loss:  1.0740392208099365
# subgraph loss:  1.076164960861206
# subgraph loss:  1.0784162282943726
# subgraph loss:  1.0696278810501099
# subgraph loss:  1.0811321973800658
# subgraph loss:  1.0823421716690063
# EPOCH loss 1.083336350440979
# Epoch:  11
# subgraph loss:  1.0826598882675171
# subgraph loss:  1.0952473878860474
# subgraph loss:  1.0871949672698975
# subgraph loss:  1.0856016874313354
# subgraph loss:  1.0435889959335327
# subgraph loss:  1.0806452274322509
# subgraph loss:  1.0761434316635132
# subgraph loss:  1.0786164999008179
# subgraph loss:  1.0731845378875733
# subgraph loss:  1.0734389543533325
# subgraph loss:  1.066319465637207
# subgraph loss:  1.0487039804458618
# subgraph loss:  1.0842508316040038
# subgraph loss:  1.0738588094711303
# subgraph loss:  1.0742282390594482
# subgraph loss:  1.0764161825180054
# subgraph loss:  1.0558264017105103
# subgraph loss:  1.0830233097076416
# subgraph loss:  1.0760011196136474
# subgraph loss:  1.0945387363433838
# subgraph loss:  1.0630407810211182
# subgraph loss:  1.0735582828521728
# subgraph loss:  1.0722139358520508
# subgraph loss:  1.0815742492675782
# subgraph loss:  1.0805511236190797
# subgraph loss:  1.070464015007019
# subgraph loss:  1.0630432844161988
# subgraph loss:  1.0590083360671998
# subgraph loss:  1.078629231452942
# subgraph loss:  1.0719815969467164
# subgraph loss:  1.0606346368789672
# subgraph loss:  1.084304976463318
# subgraph loss:  1.0547001123428346
# subgraph loss:  1.0837669134140016
# subgraph loss:  1.0654759883880616
# subgraph loss:  1.0754663944244385
# subgraph loss:  1.1005017518997193
# subgraph loss:  1.0696492910385131
# subgraph loss:  1.080201554298401
# subgraph loss:  1.0813365697860717
# subgraph loss:  1.0855773448944093
# subgraph loss:  1.0698514699935913
# subgraph loss:  1.0777592658996582
# subgraph loss:  1.088136887550354
# subgraph loss:  1.0685734272003173
# subgraph loss:  1.062478280067444
# subgraph loss:  1.0724524974822998
# subgraph loss:  1.0657623767852784
# subgraph loss:  1.0986587524414062
# subgraph loss:  1.1054172277450562
# EPOCH loss 1.0754851841926574
# Epoch:  12
# subgraph loss:  1.0822956800460815
# subgraph loss:  1.0943345069885253
# subgraph loss:  1.0829087734222411
# subgraph loss:  1.081644868850708
# subgraph loss:  1.0372833490371705
# subgraph loss:  1.0736932277679443
# subgraph loss:  1.0655551195144652
# subgraph loss:  1.071095585823059
# subgraph loss:  1.0685462713241578
# subgraph loss:  1.0691156148910523
# subgraph loss:  1.0613404750823974
# subgraph loss:  1.0409404516220093
# subgraph loss:  1.0756815433502198
# subgraph loss:  1.0569653987884522
# subgraph loss:  1.0660233736038207
# subgraph loss:  1.0726026058197022
# subgraph loss:  1.0441535472869874
# subgraph loss:  1.0732617139816285
# subgraph loss:  1.0637648105621338
# subgraph loss:  1.090222954750061
# subgraph loss:  1.0567194461822509
# subgraph loss:  1.0606245756149293
# subgraph loss:  1.062844729423523
# subgraph loss:  1.0776454210281372
# subgraph loss:  1.070746159553528
# subgraph loss:  1.0642891645431518
# subgraph loss:  1.056223487854004
# subgraph loss:  1.052405881881714
# subgraph loss:  1.0713528633117675
# subgraph loss:  1.069350004196167
# subgraph loss:  1.055952215194702
# subgraph loss:  1.0751132488250732
# subgraph loss:  1.0483870029449462
# subgraph loss:  1.0719239950180053
# subgraph loss:  1.0592156887054442
# subgraph loss:  1.0652525424957275
# subgraph loss:  1.0806662797927857
# subgraph loss:  1.041982388496399
# subgraph loss:  1.0717989444732665
# subgraph loss:  1.0751789808273315
# subgraph loss:  1.0777771949768067
# subgraph loss:  1.0654777765274048
# subgraph loss:  1.0734320163726807
# subgraph loss:  1.0779342651367188
# subgraph loss:  1.0638728857040405
# subgraph loss:  1.055248737335205
# subgraph loss:  1.0616411209106444
# subgraph loss:  1.0604401111602784
# subgraph loss:  1.0620774745941162
# subgraph loss:  1.0638586759567261
# EPOCH loss 1.0664172630310058
# Epoch:  13
# subgraph loss:  1.0716565132141114
# subgraph loss:  1.0793348550796509
# subgraph loss:  1.068052077293396
# subgraph loss:  1.0606637001037598
# subgraph loss:  1.0307887077331543
# subgraph loss:  1.0629114866256715
# subgraph loss:  1.0562692880630493
# subgraph loss:  1.0643014430999755
# subgraph loss:  1.058880352973938
# subgraph loss:  1.0572121143341064
# subgraph loss:  1.055820369720459
# subgraph loss:  1.0421616792678834
# subgraph loss:  1.0764796495437623
# subgraph loss:  1.054189419746399
# subgraph loss:  1.060319447517395
# subgraph loss:  1.0744522333145141
# subgraph loss:  1.047103476524353
# subgraph loss:  1.068007731437683
# subgraph loss:  1.0542989015579223
# subgraph loss:  1.075603199005127
# subgraph loss:  1.047960114479065
# subgraph loss:  1.061738085746765
# subgraph loss:  1.064400839805603
# subgraph loss:  1.0690117835998536
# subgraph loss:  1.069410228729248
# subgraph loss:  1.0592190980911256
# subgraph loss:  1.0472566127777099
# subgraph loss:  1.0406649827957153
# subgraph loss:  1.0602624416351318
# subgraph loss:  1.0616447687149049
# subgraph loss:  1.0463770866394042
# subgraph loss:  1.0684024095535278
# subgraph loss:  1.0402795791625976
# subgraph loss:  1.0643575191497803
# subgraph loss:  1.0549226760864259
# subgraph loss:  1.0588876962661744
# subgraph loss:  1.0732881784439088
# subgraph loss:  1.0302758932113647
# subgraph loss:  1.0594177007675172
# subgraph loss:  1.0643778085708617
# subgraph loss:  1.0752371072769165
# subgraph loss:  1.0551626443862916
# subgraph loss:  1.0685718297958373
# subgraph loss:  1.0750863790512084
# subgraph loss:  1.0610580921173096
# subgraph loss:  1.0464670658111572
# subgraph loss:  1.0561529397964478
# subgraph loss:  1.0500933170318603
# subgraph loss:  1.054315161705017
# subgraph loss:  1.0651443958282472
# EPOCH loss 1.059359021663666
# Epoch:  14
# subgraph loss:  1.0550976037979125
# subgraph loss:  1.066539716720581
# subgraph loss:  1.0654324054718018
# subgraph loss:  1.0613760709762574
# subgraph loss:  1.0271422863006592
# subgraph loss:  1.0628525018692017
# subgraph loss:  1.0452768564224244
# subgraph loss:  1.0552117586135865
# subgraph loss:  1.0489041566848756
# subgraph loss:  1.0525462865829467
# subgraph loss:  1.0512150049209594
# subgraph loss:  1.0334940433502198
# subgraph loss:  1.0595643281936646
# subgraph loss:  1.049836564064026
# subgraph loss:  1.0533127069473267
# subgraph loss:  1.0568892002105712
# subgraph loss:  1.0483633995056152
# subgraph loss:  1.0746011972427367
# subgraph loss:  1.048819375038147
# subgraph loss:  1.0678162813186645
# subgraph loss:  1.0422603607177734
# subgraph loss:  1.0486395120620728
# subgraph loss:  1.053713607788086
# subgraph loss:  1.0650821208953858
# subgraph loss:  1.0587721824645997
# subgraph loss:  1.0523473739624023
# subgraph loss:  1.0477701425552368
# subgraph loss:  1.0379340410232545
# subgraph loss:  1.0563317775726317
# subgraph loss:  1.054780697822571
# subgraph loss:  1.0376442670822144
# subgraph loss:  1.061224389076233
# subgraph loss:  1.0353165149688721
# subgraph loss:  1.0566638231277465
# subgraph loss:  1.0440911531448365
# subgraph loss:  1.0511381387710572
# subgraph loss:  1.0685096502304077
# subgraph loss:  1.0299182415008545
# subgraph loss:  1.0583138942718506
# subgraph loss:  1.0611923933029175
# subgraph loss:  1.065263319015503
# subgraph loss:  1.0506895780563354
# subgraph loss:  1.059118390083313
# subgraph loss:  1.0668183088302612
# subgraph loss:  1.056454110145569
# subgraph loss:  1.0363496780395507
# subgraph loss:  1.0454428911209106
# subgraph loss:  1.0416192531585693
# subgraph loss:  1.046251130104065
# subgraph loss:  1.0485438108444214
# EPOCH loss 1.0524497299194338
# Epoch:  15
# subgraph loss:  1.0505347490310668
# subgraph loss:  1.0632939338684082
# subgraph loss:  1.0526805639266967
# subgraph loss:  1.0555129766464233
# subgraph loss:  1.0176594257354736
# subgraph loss:  1.0517125844955444
# subgraph loss:  1.0414394855499267
# subgraph loss:  1.0445945024490357
# subgraph loss:  1.0416824340820312
# subgraph loss:  1.042356753349304
# subgraph loss:  1.0431015014648437
# subgraph loss:  1.0176241636276244
# subgraph loss:  1.0531330823898315
# subgraph loss:  1.0361347913742065
# subgraph loss:  1.0406492233276368
# subgraph loss:  1.0436782836914062
# subgraph loss:  1.0297227144241332
# subgraph loss:  1.0492778539657592
# subgraph loss:  1.0410948753356934
# subgraph loss:  1.0555748462677002
# subgraph loss:  1.0264477014541626
# subgraph loss:  1.033102560043335
# subgraph loss:  1.043143391609192
# subgraph loss:  1.05325129032135
# subgraph loss:  1.046758198738098
# subgraph loss:  1.0352309226989747
# subgraph loss:  1.0354368925094604
# subgraph loss:  1.0300803184509277
# subgraph loss:  1.0397217750549317
# subgraph loss:  1.0404252290725708
# subgraph loss:  1.0207757234573365
# subgraph loss:  1.045681071281433
# subgraph loss:  1.0191562175750732
# subgraph loss:  1.044797921180725
# subgraph loss:  1.034832239151001
# subgraph loss:  1.0374521732330322
# subgraph loss:  1.0508758544921875
# subgraph loss:  1.0178376197814942
# subgraph loss:  1.044735312461853
# subgraph loss:  1.0421595096588134
# subgraph loss:  1.0456173419952393
# subgraph loss:  1.0304481267929078
# subgraph loss:  1.0385818243026734
# subgraph loss:  1.046159839630127
# subgraph loss:  1.033799171447754
# subgraph loss:  1.0221609354019165
# subgraph loss:  1.0310031175613403
# subgraph loss:  1.0274985551834106
# subgraph loss:  1.026718831062317
# subgraph loss:  1.035722303390503
# EPOCH loss 1.0390214142799374
# Epoch:  16
# subgraph loss:  1.0302032947540283
# subgraph loss:  1.0387685537338256
# subgraph loss:  1.037377619743347
# subgraph loss:  1.0360327005386352
# subgraph loss:  0.9981390833854675
# subgraph loss:  1.0276625156402588
# subgraph loss:  1.023230218887329
# subgraph loss:  1.0347484827041626
# subgraph loss:  1.0283511400222778
# subgraph loss:  1.025457763671875
# subgraph loss:  1.0216339349746704
# subgraph loss:  0.9990375638008118
# subgraph loss:  1.0332337856292724
# subgraph loss:  1.0192455768585205
# subgraph loss:  1.0217425107955933
# subgraph loss:  1.0387445211410522
# subgraph loss:  1.0122851848602294
# subgraph loss:  1.033603048324585
# subgraph loss:  1.0217115879058838
# subgraph loss:  1.0426902770996094
# subgraph loss:  1.0069263219833373
# subgraph loss:  1.0213917732238769
# subgraph loss:  1.0315377712249756
# subgraph loss:  1.0405865907669067
# subgraph loss:  1.0283916234970092
# subgraph loss:  1.021575689315796
# subgraph loss:  1.0136438846588134
# subgraph loss:  1.0138406991958617
# subgraph loss:  1.0279113531112671
# subgraph loss:  1.0302048683166505
# subgraph loss:  1.0201070308685303
# subgraph loss:  1.0378221988677978
# subgraph loss:  1.0027121543884276
# subgraph loss:  1.034976863861084
# subgraph loss:  1.0223790645599364
# subgraph loss:  1.0262098073959351
# subgraph loss:  1.039443278312683
# subgraph loss:  1.0105100631713868
# subgraph loss:  1.035052514076233
# subgraph loss:  1.044405221939087
# subgraph loss:  1.0374873161315918
# subgraph loss:  1.0259528875350952
# subgraph loss:  1.0312368631362916
# subgraph loss:  1.0386316299438476
# subgraph loss:  1.0271317481994628
# subgraph loss:  1.0082849979400634
# subgraph loss:  1.0243965148925782
# subgraph loss:  1.0181553363800049
# subgraph loss:  1.0219287633895875
# subgraph loss:  1.0294172048568726
# EPOCH loss 1.0259230279922487
# Epoch:  17
# subgraph loss:  1.0246346235275268
# subgraph loss:  1.034133791923523
# subgraph loss:  1.0295456647872925
# subgraph loss:  1.029525637626648
# subgraph loss:  0.9935357093811035
# subgraph loss:  1.0217483520507813
# subgraph loss:  1.0105375051498413
# subgraph loss:  1.0176339149475098
# subgraph loss:  1.0185619831085204
# subgraph loss:  1.0138307571411134
# subgraph loss:  1.016316032409668
# subgraph loss:  0.9898844838142395
# subgraph loss:  1.0305423736572266
# subgraph loss:  1.0170010805130005
# subgraph loss:  1.0180590629577637
# subgraph loss:  1.0205040454864502
# subgraph loss:  1.0015843868255616
# subgraph loss:  1.0183783531188966
# subgraph loss:  1.0166236400604247
# subgraph loss:  1.032107138633728
# subgraph loss:  1.0034054279327393
# subgraph loss:  1.0190325260162354
# subgraph loss:  1.0308368921279907
# subgraph loss:  1.0317516326904297
# subgraph loss:  1.0238264560699464
# subgraph loss:  1.0109291553497315
# subgraph loss:  1.0079462766647338
# subgraph loss:  1.0037536144256591
# subgraph loss:  1.01868577003479
# subgraph loss:  1.0273289680480957
# subgraph loss:  1.0165064573287963
# subgraph loss:  1.0292580604553223
# subgraph loss:  1.0040387153625487
# subgraph loss:  1.028102946281433
# subgraph loss:  1.0090458393096924
# subgraph loss:  1.0198196411132812
# subgraph loss:  1.0318231105804443
# subgraph loss:  0.9982566714286805
# subgraph loss:  1.0222415924072266
# subgraph loss:  1.0258747577667235
# subgraph loss:  1.0300931692123414
# subgraph loss:  1.0183699607849122
# subgraph loss:  1.0256993293762207
# subgraph loss:  1.0335211515426637
# subgraph loss:  1.0218826293945313
# subgraph loss:  1.0024762392044066
# subgraph loss:  1.02162766456604
# subgraph loss:  1.0111569166183472
# subgraph loss:  1.0120832920074463
# subgraph loss:  1.018354320526123
# EPOCH loss 1.018248354434967
# Epoch:  18
# subgraph loss:  1.0158092021942138
# subgraph loss:  1.0253020763397216
# subgraph loss:  1.0234792709350586
# subgraph loss:  1.022669291496277
# subgraph loss:  0.9885206341743469
# subgraph loss:  1.021249771118164
# subgraph loss:  1.0098577976226806
# subgraph loss:  1.011541199684143
# subgraph loss:  1.0148506164550781
# subgraph loss:  1.0076306343078614
# subgraph loss:  1.011700487136841
# subgraph loss:  0.9841715335845947
# subgraph loss:  1.0213868856430053
# subgraph loss:  1.004093074798584
# subgraph loss:  1.0071380376815795
# subgraph loss:  1.014182448387146
# subgraph loss:  0.9988268733024597
# subgraph loss:  1.0169419765472412
# subgraph loss:  1.0049241781234741
# subgraph loss:  1.0261163234710693
# subgraph loss:  0.9986192107200622
# subgraph loss:  1.0090619206428528
# subgraph loss:  1.0175668716430664
# subgraph loss:  1.0267533540725708
# subgraph loss:  1.0166308641433717
# subgraph loss:  1.005155611038208
# subgraph loss:  1.003989827632904
# subgraph loss:  1.0000364661216736
# subgraph loss:  1.014210081100464
# subgraph loss:  1.021518063545227
# subgraph loss:  1.005981183052063
# subgraph loss:  1.016547179222107
# subgraph loss:  0.9907563924789429
# subgraph loss:  1.0206701755523682
# subgraph loss:  1.0048142313957213
# subgraph loss:  1.0119422197341919
# subgraph loss:  1.025962519645691
# subgraph loss:  0.9928576946258545
# subgraph loss:  1.015222930908203
# subgraph loss:  1.0268104076385498
# subgraph loss:  1.0259939432144165
# subgraph loss:  1.0115337133407594
# subgraph loss:  1.020262360572815
# subgraph loss:  1.024524712562561
# subgraph loss:  1.0112165927886962
# subgraph loss:  0.9935127854347229
# subgraph loss:  1.0147458791732789
# subgraph loss:  1.0065769672393798
# subgraph loss:  1.0096088171005249
# subgraph loss:  1.010554575920105
# EPOCH loss 1.0116805973052978
# Epoch:  19
# subgraph loss:  1.0032443284988404
# subgraph loss:  1.014294171333313
# subgraph loss:  1.0160526752471923
# subgraph loss:  1.0176157474517822
# subgraph loss:  0.9823759198188782
# subgraph loss:  1.0091725587844849
# subgraph loss:  1.005177879333496
# subgraph loss:  1.0085204601287843
# subgraph loss:  1.0013607263565063
# subgraph loss:  1.0044098854064942
# subgraph loss:  1.0053799271583557
# subgraph loss:  0.9788479804992676
# subgraph loss:  1.012723445892334
# subgraph loss:  0.9978500485420227
# subgraph loss:  0.9973239064216614
# subgraph loss:  1.0107531547546387
# subgraph loss:  0.9866289854049682
# subgraph loss:  1.009673833847046
# subgraph loss:  0.9985791087150574
# subgraph loss:  1.0276535272598266
# subgraph loss:  0.9880657434463501
# subgraph loss:  1.0008630990982055
# subgraph loss:  1.013444185256958
# subgraph loss:  1.0150109767913817
# subgraph loss:  1.0094563722610475
# subgraph loss:  0.9966559052467346
# subgraph loss:  1.0010788083076476
# subgraph loss:  0.9962274193763733
# subgraph loss:  1.0134175658226012
# subgraph loss:  1.0153377532958985
# subgraph loss:  1.0016712069511413
# subgraph loss:  1.0074391841888428
# subgraph loss:  0.9843628287315369
# subgraph loss:  1.0079549312591554
# subgraph loss:  0.9954143643379212
# subgraph loss:  1.0100857257843017
# subgraph loss:  1.0163960695266723
# subgraph loss:  0.9856230258941651
# subgraph loss:  1.0076889038085937
# subgraph loss:  1.0217174291610718
# subgraph loss:  1.0172847032546997
# subgraph loss:  1.0056939363479613
# subgraph loss:  1.007526707649231
# subgraph loss:  1.015002155303955
# subgraph loss:  1.0064597129821777
# subgraph loss:  0.9858845710754395
# subgraph loss:  1.0088139295578002
# subgraph loss:  0.996610164642334
# subgraph loss:  1.0045867681503295
# subgraph loss:  1.0070709943771363
# EPOCH loss 1.0046096682548524
# Epoch:  20
# subgraph loss:  0.9980327844619751
# subgraph loss:  1.0107295036315918
# subgraph loss:  1.0131678819656371
# subgraph loss:  1.0109666109085083
# subgraph loss:  0.9761353611946106
# subgraph loss:  1.0018151640892028
# subgraph loss:  0.9890843272209168
# subgraph loss:  0.9992313742637634
# subgraph loss:  0.9960104107856751
# subgraph loss:  0.9957752585411072
# subgraph loss:  0.9972273468971252
# subgraph loss:  0.974588406085968
# subgraph loss:  1.0108723640441895
# subgraph loss:  0.992372465133667
# subgraph loss:  0.9940345883369446
# subgraph loss:  1.007468843460083
# subgraph loss:  0.9823518753051758
# subgraph loss:  0.9999308228492737
# subgraph loss:  0.9899678826332092
# subgraph loss:  1.0114601135253907
# subgraph loss:  0.9821342468261719
# subgraph loss:  0.9923467397689819
# subgraph loss:  1.0151877641677856
# subgraph loss:  1.0104273796081542
# subgraph loss:  1.0077300786972045
# subgraph loss:  0.9886489629745483
# subgraph loss:  0.9953023672103882
# subgraph loss:  0.9843406796455383
# subgraph loss:  0.9977147579193115
# subgraph loss:  1.0070322513580323
# subgraph loss:  0.9932647585868836
# subgraph loss:  1.0041419863700867
# subgraph loss:  0.9766992688179016
# subgraph loss:  1.0048382759094239
# subgraph loss:  0.9920586943626404
# subgraph loss:  1.000577163696289
# subgraph loss:  1.0121953725814818
# subgraph loss:  0.9804946422576905
# subgraph loss:  1.008058214187622
# subgraph loss:  1.0161365032196046
# subgraph loss:  1.0105643272399902
# subgraph loss:  1.0009962797164917
# subgraph loss:  1.0074614763259888
# subgraph loss:  1.0058791637420654
# subgraph loss:  0.9991801381111145
# subgraph loss:  0.9804774522781372
# subgraph loss:  1.0026714086532593
# subgraph loss:  0.9904781460762024
# subgraph loss:  0.99502592086792
# subgraph loss:  0.9974566459655761
# EPOCH loss 0.99821488904953
# Epoch:  21
# subgraph loss:  0.9925456643104553
# subgraph loss:  1.0065924644470214
# subgraph loss:  1.0077799797058105
# subgraph loss:  1.0093132734298706
# subgraph loss:  0.9728936910629272
# subgraph loss:  0.998462188243866
# subgraph loss:  0.9905799508094788
# subgraph loss:  0.9956097841262818
# subgraph loss:  0.9938117861747742
# subgraph loss:  0.9919781804084777
# subgraph loss:  0.9950306653976441
# subgraph loss:  0.9685748100280762
# subgraph loss:  1.003387486934662
# subgraph loss:  0.9856242537498474
# subgraph loss:  0.9834318399429322
# subgraph loss:  0.9985570073127746
# subgraph loss:  0.9790457367897034
# subgraph loss:  0.9978929996490479
# subgraph loss:  0.9891151666641236
# subgraph loss:  1.0087214469909669
# subgraph loss:  0.9765596389770508
# subgraph loss:  0.9906524181365967
# subgraph loss:  1.0083150148391724
# subgraph loss:  1.0046691656112672
# subgraph loss:  1.0003369092941283
# subgraph loss:  0.9842422127723693
# subgraph loss:  0.991744589805603
# subgraph loss:  0.982917869091034
# subgraph loss:  0.9985711932182312
# subgraph loss:  1.0039852857589722
# subgraph loss:  0.9858106851577759
# subgraph loss:  0.9969316124916077
# subgraph loss:  0.978300666809082
# subgraph loss:  1.0005903482437133
# subgraph loss:  0.9896268248558044
# subgraph loss:  0.9976325154304504
# subgraph loss:  1.0049147129058837
# subgraph loss:  0.9772013783454895
# subgraph loss:  1.0061407089233398
# subgraph loss:  1.011830711364746
# subgraph loss:  1.0039757370948792
# subgraph loss:  0.9943705201148987
# subgraph loss:  1.0003686189651488
# subgraph loss:  1.004037618637085
# subgraph loss:  0.9892582535743714
# subgraph loss:  0.9758881807327271
# subgraph loss:  1.0022159218788147
# subgraph loss:  0.987683367729187
# subgraph loss:  0.995899212360382
# subgraph loss:  0.9972182393074036
# EPOCH loss 0.9942167701721192
# Epoch:  22
# subgraph loss:  0.9904004812240601
# subgraph loss:  1.0037094235420227
# subgraph loss:  1.0040957450866699
# subgraph loss:  1.0039161682128905
# subgraph loss:  0.9678924679756165
# subgraph loss:  0.9940975069999695
# subgraph loss:  0.9863664269447326
# subgraph loss:  0.9909331917762756
# subgraph loss:  0.9889720439910888
# subgraph loss:  0.9898034453392028
# subgraph loss:  0.996228563785553
# subgraph loss:  0.967287015914917
# subgraph loss:  0.9986131906509399
# subgraph loss:  0.9850630760192871
# subgraph loss:  0.9769473195075988
# subgraph loss:  0.9931469678878784
# subgraph loss:  0.975248908996582
# subgraph loss:  0.994558823108673
# subgraph loss:  0.9810629487037659
# subgraph loss:  1.0079302072525025
# subgraph loss:  0.9782983064651489
# subgraph loss:  0.9805103421211243
# subgraph loss:  0.9994391560554504
# subgraph loss:  1.0012010335922241
# subgraph loss:  0.9968111515045166
# subgraph loss:  0.9828906536102295
# subgraph loss:  0.9916638255119323
# subgraph loss:  0.9772580981254577
# subgraph loss:  0.9933871865272522
# subgraph loss:  1.0028087019920349
# subgraph loss:  0.9869755506515503
# subgraph loss:  0.9939221024513245
# subgraph loss:  0.972902774810791
# subgraph loss:  0.9974687933921814
# subgraph loss:  0.9873204469680786
# subgraph loss:  0.9963221192359925
# subgraph loss:  1.0039791703224181
# subgraph loss:  0.9771765947341919
# subgraph loss:  1.0011887073516845
# subgraph loss:  1.0085659980773927
# subgraph loss:  1.0039936780929566
# subgraph loss:  0.9872387886047364
# subgraph loss:  0.9930220007896423
# subgraph loss:  0.9988505959510803
# subgraph loss:  0.9901572823524475
# subgraph loss:  0.9708496928215027
# subgraph loss:  0.9921065688133239
# subgraph loss:  0.987063729763031
# subgraph loss:  0.9895815014839172
# subgraph loss:  0.9995595455169678
# EPOCH loss 0.9907757604122162
# Epoch:  23
# subgraph loss:  0.9946120142936706
# subgraph loss:  1.0024633526802063
# subgraph loss:  1.0007618904113769
# subgraph loss:  1.0021987318992616
# subgraph loss:  0.9678805112838745
# subgraph loss:  0.9882104873657227
# subgraph loss:  0.9800740838050842
# subgraph loss:  0.9882476210594178
# subgraph loss:  0.9822487473487854
# subgraph loss:  0.9840553164482116
# subgraph loss:  0.9818844556808471
# subgraph loss:  0.9626545548439026
# subgraph loss:  0.9969021916389466
# subgraph loss:  0.98099285364151
# subgraph loss:  0.9751089096069336
# subgraph loss:  0.9905609965324402
# subgraph loss:  0.9715672612190247
# subgraph loss:  0.9891563296318054
# subgraph loss:  0.9796489000320434
# subgraph loss:  1.0003417491912843
# subgraph loss:  0.972683560848236
# subgraph loss:  0.9808354258537293
# subgraph loss:  0.999365758895874
# subgraph loss:  0.9936172962188721
# subgraph loss:  0.9907487869262696
# subgraph loss:  0.9779042482376099
# subgraph loss:  0.98634033203125
# subgraph loss:  0.9745186805725098
# subgraph loss:  0.9895226001739502
# subgraph loss:  0.9969387412071228
# subgraph loss:  0.9816813349723816
# subgraph loss:  0.9915712356567383
# subgraph loss:  0.9658780574798584
# subgraph loss:  0.9931516528129578
# subgraph loss:  0.9800814867019654
# subgraph loss:  0.9908148884773255
# subgraph loss:  0.9992355108261108
# subgraph loss:  0.970939290523529
# subgraph loss:  0.9968340277671814
# subgraph loss:  0.9996495723724366
# subgraph loss:  1.0006433606147767
# subgraph loss:  0.987441337108612
# subgraph loss:  0.9922966599464417
# subgraph loss:  0.998862910270691
# subgraph loss:  0.9855908036231995
# subgraph loss:  0.9702644109725952
# subgraph loss:  0.9907153844833374
# subgraph loss:  0.9828379154205322
# subgraph loss:  0.9859714388847352
# subgraph loss:  0.9924452066421509
# EPOCH loss 0.9867790575027466
# Epoch:  24
# subgraph loss:  0.9897309184074402
# subgraph loss:  0.9960649132728576
# subgraph loss:  1.0005589485168458
# subgraph loss:  0.9957807183265686
# subgraph loss:  0.9607231736183166
# subgraph loss:  0.9867599725723266
# subgraph loss:  0.976509940624237
# subgraph loss:  0.9811942100524902
# subgraph loss:  0.9775460720062256
# subgraph loss:  0.9859312057495118
# subgraph loss:  0.9856541156768799
# subgraph loss:  0.9615243434906006
# subgraph loss:  0.9928607225418091
# subgraph loss:  0.9769268155097961
# subgraph loss:  0.9739502549171448
# subgraph loss:  0.9875385284423828
# subgraph loss:  0.9676777839660644
# subgraph loss:  0.9851259589195251
# subgraph loss:  0.9781613111495971
# subgraph loss:  0.9973187923431397
# subgraph loss:  0.9679243326187134
# subgraph loss:  0.9770133972167969
# subgraph loss:  0.9944368839263916
# subgraph loss:  0.991371238231659
# subgraph loss:  0.9936102032661438
# subgraph loss:  0.9732008457183838
# subgraph loss:  0.983782684803009
# subgraph loss:  0.9691653728485108
# subgraph loss:  0.9845577239990234
# subgraph loss:  0.9942944288253784
# subgraph loss:  0.9774743437767028
# subgraph loss:  0.9879197001457214
# subgraph loss:  0.9661898255348206
# subgraph loss:  0.9930176973342896
# subgraph loss:  0.9770088076591492
# subgraph loss:  0.9870057463645935
# subgraph loss:  1.0012421131134033
# subgraph loss:  0.9660834312438965
# subgraph loss:  0.9928623557090759
# subgraph loss:  0.9995790958404541
# subgraph loss:  0.9987034440040589
# subgraph loss:  0.9876994013786315
# subgraph loss:  0.9926667213439941
# subgraph loss:  0.9949368000030517
# subgraph loss:  0.9850115537643432
# subgraph loss:  0.9682900905609131
# subgraph loss:  0.9897175192832947
# subgraph loss:  0.9776689171791076
# subgraph loss:  0.9813472032546997
# subgraph loss:  0.9914161443710328
# EPOCH loss 0.98405473446846
# Epoch:  25
# subgraph loss:  0.9850618362426757
# subgraph loss:  0.995356559753418
# subgraph loss:  0.9965517163276673
# subgraph loss:  0.9966315746307373
# subgraph loss:  0.9609288096427917
# subgraph loss:  0.9841836333274842
# subgraph loss:  0.9779035687446594
# subgraph loss:  0.9783118486404419
# subgraph loss:  0.973784601688385
# subgraph loss:  0.9801637172698975
# subgraph loss:  0.984747338294983
# subgraph loss:  0.9593111753463746
# subgraph loss:  0.9929789543151856
# subgraph loss:  0.9740615606307983
# subgraph loss:  0.9716845035552979
# subgraph loss:  0.9858303666114807
# subgraph loss:  0.9678184390068054
# subgraph loss:  0.9805622220039367
# subgraph loss:  0.973934268951416
# subgraph loss:  0.9984791159629822
# subgraph loss:  0.9662622570991516
# subgraph loss:  0.9739883184432984
# subgraph loss:  0.9946220755577088
# subgraph loss:  0.99004625082016
# subgraph loss:  0.9878391265869141
# subgraph loss:  0.9734517693519592
# subgraph loss:  0.9870857715606689
# subgraph loss:  0.9726388335227967
# subgraph loss:  0.9842469215393066
# subgraph loss:  0.9955768346786499
# subgraph loss:  0.9757478713989258
# subgraph loss:  0.989324939250946
# subgraph loss:  0.9633548259735107
# subgraph loss:  0.9906497359275818
# subgraph loss:  0.9750131964683533
# subgraph loss:  0.9863257765769958
# subgraph loss:  0.9962786436080933
# subgraph loss:  0.9657550573348999
# subgraph loss:  0.9958109736442566
# subgraph loss:  0.9991729259490967
# subgraph loss:  0.9980532646179199
# subgraph loss:  0.9847650527954102
# subgraph loss:  0.9861340522766113
# subgraph loss:  0.995027220249176
# subgraph loss:  0.9854562163352967
# subgraph loss:  0.9693356990814209
# subgraph loss:  0.9915193796157837
# subgraph loss:  0.9776251554489136
# subgraph loss:  0.9847413182258606
# subgraph loss:  0.9827304601669311
# EPOCH loss 0.9827373147010803
# Epoch:  26
# subgraph loss:  0.9795820355415344
# subgraph loss:  0.9890749454498291
# subgraph loss:  0.9955390334129334
# subgraph loss:  0.9930508136749268
# subgraph loss:  0.9598195195198059
# subgraph loss:  0.9828051328659058
# subgraph loss:  0.9701611518859863
# subgraph loss:  0.9809649109840393
# subgraph loss:  0.974131977558136
# subgraph loss:  0.9792541027069092
# subgraph loss:  0.9843494892120361
# subgraph loss:  0.962352192401886
# subgraph loss:  0.9935524582862854
# subgraph loss:  0.9755523085594178
# subgraph loss:  0.9677773475646972
# subgraph loss:  0.9814528107643128
# subgraph loss:  0.9692550659179687
# subgraph loss:  0.9844857811927795
# subgraph loss:  0.9778899312019348
# subgraph loss:  0.9971607446670532
# subgraph loss:  0.967333459854126
# subgraph loss:  0.9773628234863281
# subgraph loss:  0.9952097654342651
# subgraph loss:  0.9912405014038086
# subgraph loss:  0.9865618348121643
# subgraph loss:  0.9726381659507751
# subgraph loss:  0.9793767809867859
# subgraph loss:  0.9760416865348815
# subgraph loss:  0.990405797958374
# subgraph loss:  0.9973321437835694
# subgraph loss:  0.9801427721977234
# subgraph loss:  0.9829380989074707
# subgraph loss:  0.9588093638420105
# subgraph loss:  0.9903655648231506
# subgraph loss:  0.9738729119300842
# subgraph loss:  0.9880757451057434
# subgraph loss:  0.9958394169807434
# subgraph loss:  0.9647985935211182
# subgraph loss:  0.9980417370796204
# subgraph loss:  0.9961883068084717
# subgraph loss:  0.9935455560684204
# subgraph loss:  0.985215175151825
# subgraph loss:  0.9878445744514466
# subgraph loss:  0.9931255102157592
# subgraph loss:  0.9839097738265992
# subgraph loss:  0.9650820970535279
# subgraph loss:  0.9838613271713257
# subgraph loss:  0.9738655328750611
# subgraph loss:  0.9812738060951233
# subgraph loss:  0.9866026163101196
# EPOCH loss 0.9819022638797762
# Epoch:  27
# subgraph loss:  0.9766894578933716
# subgraph loss:  0.9915308952331543
# subgraph loss:  0.9915717959403991
# subgraph loss:  0.9923036694526672
# subgraph loss:  0.9575853943824768
# subgraph loss:  0.9806491136550903
# subgraph loss:  0.9696770310401917
# subgraph loss:  0.976984691619873
# subgraph loss:  0.9731484293937683
# subgraph loss:  0.9766615390777588
# subgraph loss:  0.9806615710258484
# subgraph loss:  0.9585526823997498
# subgraph loss:  0.9900574922561646
# subgraph loss:  0.9724974870681763
# subgraph loss:  0.9702976107597351
# subgraph loss:  0.9860850930213928
# subgraph loss:  0.9688729047775269
# subgraph loss:  0.983236801624298
# subgraph loss:  0.9746204018592834
# subgraph loss:  0.9949654817581177
# subgraph loss:  0.9631470084190369
# subgraph loss:  0.9729979872703552
# subgraph loss:  0.9875430345535279
# subgraph loss:  0.9860478162765502
# subgraph loss:  0.9872823476791381
# subgraph loss:  0.9718749403953553
# subgraph loss:  0.9794139266014099
# subgraph loss:  0.9715282559394837
# subgraph loss:  0.9866554141044617
# subgraph loss:  0.9931780099868774
# subgraph loss:  0.9760910272598267
# subgraph loss:  0.9793359637260437
# subgraph loss:  0.9592549085617066
# subgraph loss:  0.989855694770813
# subgraph loss:  0.9736449956893921
# subgraph loss:  0.9869994997978211
# subgraph loss:  0.9950382828712463
# subgraph loss:  0.9642711162567139
# subgraph loss:  0.9919893383979798
# subgraph loss:  0.9927555918693542
# subgraph loss:  0.987962293624878
# subgraph loss:  0.9796348333358764
# subgraph loss:  0.9832915425300598
# subgraph loss:  0.9902644157409668
# subgraph loss:  0.9807487964630127
# subgraph loss:  0.9669571399688721
# subgraph loss:  0.9840837597846985
# subgraph loss:  0.9743767023086548
# subgraph loss:  0.9813285946846009
# subgraph loss:  0.9844171285629273
# EPOCH loss 0.9797723982334137
# Epoch:  28
# subgraph loss:  0.9779579281806946
# subgraph loss:  0.990868091583252
# subgraph loss:  0.9897830367088318
# subgraph loss:  0.9931286096572876
# subgraph loss:  0.9582703828811645
# subgraph loss:  0.9817494511604309
# subgraph loss:  0.971600079536438
# subgraph loss:  0.9739600896835328
# subgraph loss:  0.9747853875160217
# subgraph loss:  0.9763310432434082
# subgraph loss:  0.9794126629829407
# subgraph loss:  0.9550966501235962
# subgraph loss:  0.9870688438415527
# subgraph loss:  0.9713797092437744
# subgraph loss:  0.9662841558456421
# subgraph loss:  0.9864400148391723
# subgraph loss:  0.9686912894248962
# subgraph loss:  0.9807087063789368
# subgraph loss:  0.9690405249595642
# subgraph loss:  0.9946216106414795
# subgraph loss:  0.962166941165924
# subgraph loss:  0.9750037074089051
# subgraph loss:  0.9905256271362305
# subgraph loss:  0.9888997316360474
# subgraph loss:  0.9837304353713989
# subgraph loss:  0.9700418949127197
# subgraph loss:  0.9759313106536865
# subgraph loss:  0.9658343672752381
# subgraph loss:  0.9787909507751464
# subgraph loss:  0.9883021593093873
# subgraph loss:  0.9726211905479432
# subgraph loss:  0.9806989192962646
# subgraph loss:  0.9569559693336487
# subgraph loss:  0.9868815302848816
# subgraph loss:  0.9697545766830444
# subgraph loss:  0.9860445976257324
# subgraph loss:  0.9985276460647583
# subgraph loss:  0.9660436272621155
# subgraph loss:  0.9948252439498901
# subgraph loss:  0.996538770198822
# subgraph loss:  0.9938870072364807
# subgraph loss:  0.9847585797309876
# subgraph loss:  0.982364559173584
# subgraph loss:  0.9897499561309815
# subgraph loss:  0.9790140986442566
# subgraph loss:  0.9620872139930725
# subgraph loss:  0.9857825636863708
# subgraph loss:  0.9747663974761963
# subgraph loss:  0.9761258721351623
# subgraph loss:  0.9813784480094909
# EPOCH loss 0.9789042432308197
# Epoch:  29
# subgraph loss:  0.9758397102355957
# subgraph loss:  0.9891990900039673
# subgraph loss:  0.9901928305625916
# subgraph loss:  0.9915621042251587
# subgraph loss:  0.9540768146514893
# subgraph loss:  0.9785158038139343
# subgraph loss:  0.9714132785797119
# subgraph loss:  0.9754091739654541
# subgraph loss:  0.9731158018112183
# subgraph loss:  0.9770532369613647
# subgraph loss:  0.9790217041969299
# subgraph loss:  0.955096983909607
# subgraph loss:  0.9875738978385925
# subgraph loss:  0.9709734201431275
# subgraph loss:  0.9644072413444519
# subgraph loss:  0.9813816547393799
# subgraph loss:  0.9611589193344117
# subgraph loss:  0.9765304923057556
# subgraph loss:  0.9706027507781982
# subgraph loss:  0.9920703291893005
# subgraph loss:  0.9621894598007202
# subgraph loss:  0.9747689008712769
# subgraph loss:  0.9920131921768188
# subgraph loss:  0.985429048538208
# subgraph loss:  0.9854498505592346
# subgraph loss:  0.9708912372589111
# subgraph loss:  0.9731476783752442
# subgraph loss:  0.9634521484375
# subgraph loss:  0.9805743336677551
# subgraph loss:  0.9883012890815734
# subgraph loss:  0.9695712685585022
# subgraph loss:  0.9774466633796692
# subgraph loss:  0.9560585021972656
# subgraph loss:  0.9857904553413391
# subgraph loss:  0.9725825428962708
# subgraph loss:  0.9836707830429077
# subgraph loss:  0.9934782147407532
# subgraph loss:  0.9629233121871948
# subgraph loss:  0.989260458946228
# subgraph loss:  0.9970662713050842
# subgraph loss:  0.9879143834114075
# subgraph loss:  0.9812060594558716
# subgraph loss:  0.982306706905365
# subgraph loss:  0.9882783651351928
# subgraph loss:  0.9783185720443726
# subgraph loss:  0.9649795413017273
# subgraph loss:  0.9813401699066162
# subgraph loss:  0.9701453804969787
# subgraph loss:  0.977994155883789
# # 2022-11-30 15:44:34.754 [INFO] [4270138861.py:82] Part 3, training GAT end!
# subgraph loss:  0.9806500196456909
# EPOCH loss 0.9774478840827945

# %%
cellmodel=Sencell().to(device)
optimizer = torch.optim.Adam(cellmodel.parameters(), lr=0.001, 
                                weight_decay=1e-3)
all_marker_index=sen_gene_ls
    
iteration_results=[]
for iteration in range(5):
    logger.info(f"iteration: {iteration}")
    sampled_graph,sencell_dict,nonsencell_dict,cell_clusters,big_graph_index_dict=sub_sampling_by_random(graph_nx,
                                                            sen_gene_ls,
                                                            nonsen_gene_ls,
                                                            GAT_model,
                                                            args,
                                                            all_marker_index,
                                                            n_gene=len(all_marker_index),                                                        
                                                            gene_rate=0.3,cell_rate=0.5,
                                                            debug=False)
    old_sengene_indexs=all_marker_index
    for epoch in range(10):
        logger.info(f"epoch: {epoch}")
        old_sencell_dict=sencell_dict
        cellmodel,sencell_dict,nonsencell_dict=cell_optim(cellmodel,optimizer,
                                                          sencell_dict,nonsencell_dict,args,
                                                         train=True)
        sampled_graph=update_cell_embeddings(sampled_graph,sencell_dict,nonsencell_dict)
        sencell_dict,nonsencell_dict, \
        sen_gene_indexs,nonsen_gene_indexs=identify_sengene_then_sencell(sampled_graph,GAT_model,
                                                                      sencell_dict,nonsencell_dict,
                                                                      cell_clusters,
                                                                      big_graph_index_dict,
                                                                      len(all_marker_index),args)

        get_sencell_cover(old_sencell_dict,sencell_dict)
        get_sengene_cover(old_sengene_indexs,sen_gene_indexs)
        old_sengene_indexs=sen_gene_indexs
    iteration_results.append([sen_gene_indexs,sencell_dict])
# Out:
# # 2022-11-30 16:11:22.899 [INFO] [2770481884.py:5] iteration: 0
# Start sampling subgraph randomly ...
#     Sengene num: 362, Nonsengen num: 362
# subgraph total node num: (39131,)
# After sampling, gene num:  tensor(724)
# # 2022-11-30 16:28:03.701 [INFO] [2770481884.py:17] epoch: 0
# obj saved ./outputs/disease_cell_score_dict
#     Sencell num: 200, Nonsencell num: 2000
# sencell cover: 0.995
# sengene cover: 0.9640883977900553
# 14.79797649383545
# 14.861987113952637
# 14.982522964477539
# 14.98729133605957
# 14.878374099731445
# 14.762664794921875
# 14.708982467651367
# 14.725641250610352
# 14.764449119567871
# 14.758496284484863
# 14.693153381347656
# 14.617863655090332
# 14.586393356323242
# 14.600530624389648
# 14.621828079223633
# 14.607587814331055
# 14.557353973388672
# 14.507540702819824
# 14.484506607055664
# 14.48620319366455
# rechoice sengene num: 362 rechoice nonsengene num: 362

# %%
torch.save([sencell_dict,sen_gene_indexs],'./outputs/disease_outputs.data')

# %%
# Out:
# # 2022-11-28 13:35:49.829 [INFO] [4290767024.py:5] iteration: 0
# Start sampling subgraph randomly ...
#     Sengene num: 343, Nonsengen num: 343
# subgraph total node num: (8288,)
# After sampling, gene num:  tensor(686)
# # 2022-11-28 13:38:45.396 [INFO] [4290767024.py:18] epoch: 0
# [0.00122944 0.00172688 0.00234938 ... 0.39748853 0.54444087 0.57576734]
#     Sencell num: 196, Nonsencell num: 1960
# 24.877323150634766
# 18.285886764526367
# 18.5355167388916
# 17.720273971557617
# 16.566776275634766
# 17.011201858520508
# 17.641918182373047
# 17.057353973388672
# 16.591041564941406
# 16.47360610961914
# 16.787492752075195
# 16.910785675048828
# 16.50572395324707
# 16.403051376342773
# 16.437009811401367
# 16.507965087890625
# 16.56315803527832
# 16.55409812927246
# 16.479291915893555
# 16.388391494750977
# rechoice sengene num: 343 rechoice nonsengene num: 343
# [0.00390377 0.00416368 0.0044079  ... 0.08458243 0.08706584 0.08825421]
#     Sencell num: 0, Nonsencell num: 7602
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#      23 sampled_graph=update_cell_embeddings(sampled_graph,sencell_dict,nonsencell_dict)
#      24 sencell_dict,nonsencell_dict, \
#      25 sen_gene_indexs,nonsen_gene_indexs=identify_sengene_then_sencell(sampled_graph,GAT_model,
#      26                                                               sencell_dict,nonsencell_dict,
#      27                                                               cell_clusters,
#      28                                                               big_graph_index_dict,
#      29                                                               len(all_marker_index))
# ---> 31 get_sencell_cover(old_sencell_dict,sencell_dict)
#      32 get_sengene_cover(old_sengene_indexs,sen_gene_indexs)
#      33 old_sengene_indexs=sen_gene_indexs
#
# Input In [1], in get_sencell_cover(old_sencell_dict, sencell_dict)
#      79 set2=set(list(sencell_dict.keys()))
#      80 set3=set1.intersection(set2)
# ---> 81 print('sencell cover:',len(set3)/len(set2))
#      83 return len(set3)/len(set2)
#
# ZeroDivisionError: division by zero

# %%
import scanpy as sp
path="/users/PCON0022/haocheng/Basu_lab/rmarkdown/combined_g8.h5ad"
adata=sp.read_h5ad(path)
adata=adata[adata.obs['disease']!='Healthy']

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 38407 × 24543
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.ribo', 'percent.mito', 'count.mad.higher', 'integrated_snn_res.0.2', 'seurat_clusters', 'cell_type_seurat', 'disease', 'location'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_pca', 'X_umap'

# %%
graph_nx.nodes[10956]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 graph_nx.nodes[10956]
#
# File ~/.conda/envs/deepmaps_env/lib/python3.8/site-packages/networkx/classes/reportviews.py:187, in NodeView.__getitem__(self, n)
#     186 def __getitem__(self, n):
# --> 187     return self._nodes[n]
#
# KeyError: 10956

# %%
import networkx as nx

# %%
g_index,c_index = np.nonzero(gene_cell)
print('The number of edges:',len(g_index))
# 加上偏移量作为cell的节点标号
gene_num = gene_cell.shape[0]
c_index += gene_num
edge_index=torch.tensor([g_index, c_index], dtype=torch.long)

# step 2: build nx graph, add attributes
graph_nx=nx.Graph(edge_index.T.tolist())

# 再加一个属性，是每个节点在大图上的index
for i in range(gene_num):
    graph_nx.nodes[i]['type']='g'
    graph_nx.nodes[i]['index']=i
    graph_nx.nodes[i]['name']=gene_names[i]
    graph_nx.nodes[i]['is_sen']= i in sen_gene_ls
# Out:
# The number of edges: 3177602
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 12>()
#      11 # 再加一个属性，是每个节点在大图上的index
#      12 for i in range(gene_num):
# ---> 13     graph_nx.nodes[i]['type']='g'
#      14     graph_nx.nodes[i]['index']=i
#      15     graph_nx.nodes[i]['name']=gene_names[i]
#
# File ~/.conda/envs/deepmaps_env/lib/python3.8/site-packages/networkx/classes/reportviews.py:187, in NodeView.__getitem__(self, n)
#     186 def __getitem__(self, n):
# --> 187     return self._nodes[n]
#
# KeyError: 5

# %%
graph_nx.nodes[5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 graph_nx.nodes[5]
#
# File ~/.conda/envs/deepmaps_env/lib/python3.8/site-packages/networkx/classes/reportviews.py:187, in NodeView.__getitem__(self, n)
#     186 def __getitem__(self, n):
# --> 187     return self._nodes[n]
#
# KeyError: 5

# %%
sum(edge_index[0]==5)
# Out:
# tensor(0)

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 7602 × 24543
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.ribo', 'percent.mito', 'count.mad.higher', 'integrated_snn_res.0.2', 'seurat_clusters', 'cell_type_seurat', 'disease', 'location'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_pca', 'X_umap'

# %%
list(adata.var.index).index('FGG')
# Out:
# 5110

# %%
adata.var.iloc[5110,:]
# Out:
# vst.mean                      0.044274
# vst.variance                  0.695201
# vst.variance.expected         0.058568
# vst.variance.standardized    11.399175
# vst.variable                      True
# Name: FGG, dtype: object

# %%
max(adata.X.toarray()[:,5110])
# Out:
# 0.0

# %%
list(adata.var[adata.var['vst.variable']==True].index)
# Out:
# ['HES4',
#  'ISG15',
#  'TTLL10',
#  'TNFRSF4',
#  'MXRA8',
#  'CFAP74',
#  'ERRFI1',
#  'FHAD1',
#  'EPHA2',
#  'IFFO2',
#  'NBL1',
#  'PLA2G2A',
#  'PLA2G2D',
#  'UBXN10',
#  'CAMK2N1',
#  'ALPL',
#  'HSPG2',
#  'WNT4',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'ID3',
#  'CLIC4',
#  'STMN1',
#  'CD52',
#  'SFN',
#  'SYTL1',
#  'FCN3',
#  'CD164L2',
#  'IFI6',
#  'FABP3',
#  'SERINC2',
#  'DCDC2B',
#  'GJA4',
#  'CLSPN',
#  'TEKT2',
#  'EVA1B',
#  'DNALI1',
#  'CDCA8',
#  'MACF1',
#  'MFSD2A',
#  'EDN2',
#  'CCDC30',
#  'SLC2A1',
#  'FAM183A',
#  'CFAP57',
#  'CDC20',
#  'PTPRF',
#  'KIF2C',
#  'TCTEX1D4',
#  'CCDC17',
#  'PIK3R3',
#  'TSPAN1',
#  'CYP4B1',
#  'RAB3B',
#  'PODN',
#  'LDLRAD1',
#  'DHCR24',
#  'FYB2',
#  'TACSTD2',
#  'C1orf87',
#  'NFIA',
#  'NFIA-AS2',
#  'TCTEX1D1',
#  'WDR78',
#  'C1orf141',
#  'GADD45A',
#  'GNG12',
#  'DEPDC1',
#  'ERICH3',
#  'AK5',
#  'NEXN',
#  'DNAJB4',
#  'AC103591.3',
#  'IFI44L',
#  'ADGRL4',
#  'DNASE2B',
#  'WDR63',
#  'DDAH1',
#  'CCN1',
#  'CLCA2',
#  'GBP1',
#  'GBP6',
#  'LRRC8B',
#  'GCLM',
#  'ARHGAP29',
#  'F3',
#  'CNN3',
#  'PALMD',
#  'VCAM1',
#  'C1orf194',
#  'KIAA1324',
#  'GSTM3',
#  'CHI3L2',
#  'PIFO',
#  'RHOC',
#  'DENND2C',
#  'LINC01765',
#  'CD2',
#  'SPAG17',
#  'PHGDH',
#  'AC253572.2',
#  'LINC02802',
#  'FMO5',
#  'GJA5',
#  'ECM1',
#  'CTSK',
#  'SELENBP1',
#  'RIIAD1',
#  'S100A9',
#  'S100A12',
#  'S100A8',
#  'S100A2',
#  'S100A16',
#  'S100A14',
#  'S100A1',
#  'C1orf189',
#  'KCNN3',
#  'CKS1B',
#  'EFNA1',
#  'MUC1',
#  'FDPS',
#  'RAB25',
#  'NES',
#  'CRABP2',
#  'LRRC71',
#  'FCRL5',
#  'CD1A',
#  'CD1C',
#  'CD1B',
#  'CD1E',
#  'CADM3-AS1',
#  'ACKR1',
#  'FCER1A',
#  'CFAP45',
#  'LINC01133',
#  'ATP1A2',
#  'PEA15',
#  'CD84',
#  'SLAMF7',
#  'ITLN1',
#  'ITLN2',
#  'ADAMTS4',
#  'CFAP126',
#  'HSPA6',
#  'FCGR2B',
#  'UAP1',
#  'DDR2',
#  'CCDC190',
#  'RGS5',
#  'NUF2',
#  'XCL2',
#  'XCL1',
#  'DPT',
#  'ATP1B1',
#  'CCDC181',
#  'SELP',
#  'SELE',
#  'PRRX1',
#  'FMO3',
#  'FMO2',
#  'FMO1',
#  'TNFSF4',
#  'GAS5',
#  'QSOX1',
#  'RGS16',
#  'LAMC1',
#  'LAMC2',
#  'APOBEC4',
#  'HMCN1',
#  'PRG4',
#  'PTGS2',
#  'RGS1',
#  'RGS2',
#  'CFH',
#  'ASPM',
#  'NEK7',
#  'KIF14',
#  'PKP1',
#  'TNNT2',
#  'LAD1',
#  'CSRP1',
#  'NAV1',
#  'LMOD1',
#  'ELF3',
#  'CHI3L1',
#  'CHIT1',
#  'FMOD',
#  'PRELP',
#  'KISS1',
#  'CTSE',
#  'RHEX',
#  'IL10',
#  'IL24',
#  'PIGR',
#  'C1orf116',
#  'C4BPA',
#  'CD34',
#  'MIR205HG',
#  'LAMB3',
#  'HSD11B1-AS1',
#  'G0S2',
#  'IRF6',
#  'NEK2',
#  'PROX1',
#  'PTPN14',
#  'CENPF',
#  'SPATA17',
#  'TGFB2',
#  'LINC01705',
#  'ENAH',
#  'PGBD5',
#  'AGT',
#  'C1orf198',
#  'CHML',
#  'KIF26B',
#  'NLRP3',
#  'SH3YL1',
#  'ALKAL2',
#  'PXDN',
#  'RSAD2',
#  'MBOAT2',
#  'RRM2',
#  'ODC1',
#  'LRATD1',
#  'SDC1',
#  'ADGRF3',
#  'DRC1',
#  'KCNK3',
#  'CENPA',
#  'EMILIN1',
#  'LBH',
#  'LINC01936',
#  'LTBP1',
#  'CRIM1',
#  'CYP1B1',
#  'MORN2',
#  'EPAS1',
#  'EPCAM',
#  'C2orf73',
#  'SPTBN1',
#  'EFEMP1',
#  'GKN2',
#  'CD207',
#  'EGR4',
#  'ACTG2',
#  'WDR54',
#  'TACR1',
#  'AC007681.1',
#  'DNAH6',
#  'SFTPB',
#  'GNLY',
#  'LINC01943',
#  'CYTOR',
#  'IGKC',
#  'IGKV3-11',
#  'IGKV3-20',
#  'TEKT4',
#  'AC008268.1',
#  'LINC00342',
#  'DUSP2',
#  'NCAPH',
#  'VWA3B',
#  'KIAA1211L',
#  'TSGA10',
#  'MAP4K4',
#  'IL1R2',
#  'IL1R1',
#  'IL1RL1',
#  'FHL2',
#  'ECRG4',
#  'MALL',
#  'NPHP1',
#  'BUB1',
#  'CKAP2L',
#  'IL1A',
#  'AC079753.2',
#  'IL1B',
#  'IL1RN',
#  'MARCO',
#  'AC013457.1',
#  'SCTR',
#  'CFAP221',
#  'TFCP2L1',
#  'CCDC74A',
#  'MAP3K19',
#  'RND3',
#  'TNFAIP6',
#  'GALNT5',
#  'ITGB6',
#  'DPP4',
#  'COBLL1',
#  'SCN9A',
#  'SCN7A',
#  'NOSTRIN',
#  'DHRS9',
#  'LRP2',
#  'CCDC173',
#  'ITGA6',
#  'TTN',
#  'CCDC141',
#  'ZNF385B',
#  'CERKL',
#  'CALCRL',
#  'TFPI',
#  'COL3A1',
#  'COL5A2',
#  'SLC40A1',
#  'MYO1B',
#  'CAVIN2',
#  'DNAH7',
#  'AC013264.1',
#  'SGO2',
#  'KIAA2012',
#  'CTLA4',
#  'MAP2',
#  'ACADL',
#  'ERBB4',
#  'SPAG16',
#  'FN1',
#  'IGFBP2',
#  'IGFBP5',
#  'RUFY4',
#  'CFAP65',
#  'TUBA4B',
#  'DES',
#  'LINC02832',
#  'SGPP2',
#  'AP1S3',
#  'SERPINE2',
#  'AC016717.2',
#  'COL4A4',
#  'CCL20',
#  'HJURP',
#  'IQCA1',
#  'COL6A3',
#  'RAMP1',
#  'HES6',
#  'TRAF3IP1',
#  'GPC1',
#  'AC110619.1',
#  'LMCD1',
#  'OXTR',
#  'SRGAP3',
#  'SRGAP3-AS2',
#  'TMEM40',
#  'FBLN2',
#  'GALNT15',
#  'EFHB',
#  'SGO1',
#  'NEK10',
#  'RPSA',
#  'VIPR1',
#  'CLEC3B',
#  'TMEM158',
#  'XCR1',
#  'LTF',
#  'KIF9',
#  'CAMP',
#  'CDHR4',
#  'HYAL2',
#  'ZMYND10',
#  'CACNA2D2',
#  'TNNC1',
#  'DNAH12',
#  'FLNB',
#  'DNASE1L3',
#  'FAM107A',
#  'FAM3D',
#  'SNTN',
#  'ADAMTS9',
#  'VGLL3',
#  'EPHA3',
#  'GPR15',
#  'DCBLD2',
#  'COL8A1',
#  'FILIP1L',
#  'ABI3BP',
#  'IFT57',
#  'DZIP3',
#  'PHLDB2',
#  'CCDC80',
#  'CFAP44',
#  'UPK1B',
#  'MAATS1',
#  'FSTL1',
#  'CSTA',
#  'MYLK',
#  'HEG1',
#  'ALDH1L1',
#  'CFAP100',
#  'MGLL',
#  'GATA2',
#  'COL6A5',
#  'SLCO2A1',
#  'IL20RB',
#  'CLDN18',
#  'RBP1',
#  'PLOD2',
#  'CPA3',
#  'CP',
#  'TM4SF18',
#  'TM4SF1',
#  'ANKUB1',
#  'PFN2',
#  'P2RY13',
#  'VEPH1',
#  'PTX3',
#  'LXN',
#  'RARRES1',
#  'SMC4',
#  'ZBBX',
#  'CLDN11',
#  'RPL22L1',
#  'TMEM212',
#  'TNFSF10',
#  'LINC00578',
#  'ZMAT3',
#  'CCDC39',
#  'SOX2',
#  'LAMP3',
#  'LIPH',
#  'IGF2BP2',
#  'ST6GAL1',
#  'TP63',
#  'CLDN1',
#  'ATP13A4',
#  'HES1',
#  'APOD',
#  'MUC20',
#  'MUC4',
#  'TFRC',
#  'TCTEX1D2',
#  'TM4SF19',
#  'IQCG',
#  'SPON2',
#  'TACC3',
#  'FGFR3',
#  'S100P',
#  'AFAP1',
#  'HTRA3',
#  'FGFBP1',
#  'FGFBP2',
#  'PROM1',
#  'NCAPG',
#  'SLIT2',
#  'SOD3',
#  'SLC34A2',
#  'PCDH7',
#  'DTHD1',
#  'FAM114A1',
#  'UCHL1',
#  'LIMCH1',
#  'CORIN',
#  'OCIAD2',
#  'SPATA18',
#  'PDGFRA',
#  'KIT',
#  'KDR',
#  'HOPX',
#  'IGFBP7',
#  'JCHAIN',
#  'RASSF6',
#  'CXCL8',
#  'CXCL6',
#  'CXCL1',
#  'PPBP',
#  'CXCL5',
#  'CXCL3',
#  'CXCL2',
#  'EREG',
#  'AREG',
#  'PARM1',
#  'CXCL9',
#  'CXCL10',
#  'CXCL11',
#  'SEPTIN11',
#  'CXCL13',
#  'ANXA3',
#  'CFAP299',
#  'PLAC8',
#  'CDS1',
#  'MAPK10',
#  'PTPN13',
#  'HSD17B13',
#  'SPARCL1',
#  'IBSP',
#  'SPP1',
#  'HERC5',
#  'MMRN1',
#  'HPGDS',
#  'TSPAN5',
#  'ADH1B',
#  'ADH1C',
#  'ADH7',
#  'EMCN',
#  'SLC39A8',
#  'CENPE',
#  'NPNT',
#  'DKK2',
#  'ARSJ',
#  'SNHG8',
#  'SYNPO2',
#  'USP53',
#  'PDE5A',
#  'NDNF',
#  'TNIP3',
#  'CCNA2',
#  'FGF2',
#  'SPRY1',
#  'HSPA4L',
#  'AC078850.1',
#  'PCDH18',
#  'SLC7A11',
#  'CLGN',
#  'LINC02432',
#  'HHIP',
#  'TTC29',
#  'TMEM154',
#  'SFRP2',
#  'FGG',
#  'TDO2',
#  'FNIP2',
#  'MSMO1',
#  'PALLD',
#  'SCRG1',
#  'VEGFC',
#  'CENPU',
#  'SNX25',
#  'PDLIM3',
#  'SORBS2',
#  'FAT1',
#  'LPCAT1',
#  'C5orf49',
#  'SEMA5A',
#  'ROPN1L',
#  'LINC01513',
#  'DNAH5',
#  'MYO10',
#  'CDH6',
#  'C1QTNF3',
#  'RAI14',
#  'SPEF2',
#  'IL7R',
#  'CAPSL',
#  'SLC1A3',
#  'LIFR',
#  'DAB2',
#  'AC114977.1',
#  'C7',
#  'C6',
#  'PLCXD3',
#  'SELENOP',
#  'HMGCS1',
#  'ITGA2',
#  'FST',
#  'GZMK',
#  'GZMA',
#  'CDC20B',
#  'GPX8',
#  'MCIDAS',
#  'CCNO',
#  'IL6ST',
#  'PLK2',
#  'RGS7BP',
#  'MAST4',
#  'CCNB1',
#  'OCLN',
#  'MAP1B',
#  'FOXD1',
#  'ENC1',
#  'F2R',
#  'VCAN',
#  'LUCAT1',
#  'NR2F1',
#  'FAM81B',
#  'RHOBTB3',
#  'TMEM232',
#  'TSLP',
#  'STARD4-AS1',
#  'NREP',
#  'EPB41L4A-AS1',
#  'LOX',
#  'AC113349.1',
#  'CSF2',
#  'PDLIM4',
#  'IL13',
#  'PITX1',
#  'CXCL14',
#  'TGFBI',
#  'SPOCK1',
#  'NME5',
#  'KIF20A',
#  'EGR1',
#  'SLC23A1',
#  'MZB1',
#  'AC010378.2',
#  'CD14',
#  'SPINK1',
#  'SCGB3A2',
#  'SPINK5',
#  'SPINK6',
#  'CARMN',
#  'PDGFRB',
#  'GM2A',
#  'FAT2',
#  'SPARC',
#  'FABP6',
#  'PTTG1',
#  'HMMR',
#  'SLIT3',
#  'LINC01366',
#  'GABRP',
#  'NEURL1B',
#  'DBN1',
#  'LTC4S',
#  'SCGB3A1',
#  'FLT4',
#  'BTNL9',
#  'IRF4',
#  'FOXQ1',
#  'FOXC1',
#  'F13A1',
#  'DSP',
#  'TFAP2A',
#  'EDN1',
#  'AL021978.1',
#  'STMND1',
#  'ID4',
#  'SOX4',
#  'HIST1H1A',
#  'HIST1H3B',
#  'HIST1H1C',
#  'HIST1H4C',
#  'HIST1H1E',
#  'HIST1H3D',
#  'HIST1H1D',
#  'HIST1H3G',
#  'AL121936.1',
#  'HIST1H2AG',
#  'HIST1H2AH',
#  'HIST1H2AI',
#  'HIST1H2AJ',
#  'HIST1H2AL',
#  'HIST1H1B',
#  'LINC02829',
#  'RNF39',
#  'TUBB',
#  'IER3',
#  'SFTA2',
#  'MUC21',
#  'TNF',
#  'LTB',
#  'HSPA1A',
#  'HSPA1B',
#  'SNHG32',
#  'SLC44A4',
#  'CFB',
#  'TNXB',
#  'AGER',
#  'HLA-DRB5',
#  'HLA-DRB1',
#  'HLA-DQA1',
#  'HLA-DQA2',
#  'HLA-DQB2',
#  'RPS18',
#  'HMGA1',
#  'CDKN1A',
#  'PI16',
#  'KIF6',
#  'TREM2',
#  'PGC',
#  'AL512274.1',
#  'C6orf132',
#  'RSPH9',
#  'CLIC5',
#  'PLA2G7',
#  'ANKRD66',
#  'ADGRF5',
#  'ADGRF1',
#  'CRISP2',
#  'EFHC1',
#  'TRAM2',
#  'GSTA2',
#  'GSTA1',
#  'GSTA3',
#  'BMP5',
#  'DST',
#  'AL365226.2',
#  'COL12A1',
#  'FILIP1',
#  'TTK',
#  'NT5E',
#  'CFAP206',
#  'FHL5',
#  'CD24',
#  'PPIL6',
#  'SLC16A10',
#  'FAM229B',
#  'LAMA4',
#  'MARCKS',
#  'COL10A1',
#  'CALHM6',
#  'RSPH4A',
#  'ROS1',
#  'FAM184A',
#  'GJA1',
#  'PKIB',
#  'TPD52L1',
#  'NCOA7',
#  'CENPW',
#  'RSPO3',
#  'LAMA2',
#  'CCN2',
#  'VNN3',
#  'AL591115.1',
#  'TCF21',
#  'SGK1',
#  'IL22RA2',
#  'TNFAIP3',
#  'PERP',
#  'ARFGEF3',
#  'ECT2L',
#  'CITED2',
#  'RAB32',
#  'ADGB',
#  'RAET1E',
#  'AKAP12',
#  'CCDC170',
#  'SYNE1',
#  'MYCT1',
#  'CNKSR3',
#  'PACRG',
#  'C6orf118',
#  'AL121956.6',
#  'THBS2',
#  'ZFAND2A',
#  'TMEM184A',
#  'FSCN1',
#  'COL28A1',
#  'AC013470.2',
#  'ETV1',
#  'MEOX2',
#  'AGR2',
#  'AGR3',
#  'MACC1',
#  'ITGB8',
#  'ABCB5',
#  'DNAH11',
#  'IL6',
#  'GPNMB',
#  'GARS',
#  'INMT',
#  'AQP1',
#  'PPP1R17',
#  'PDE1C',
#  'ANLN',
#  'SFRP4',
#  'SUGCT',
#  'INHBA',
#  'AEBP1',
#  'RAMP3',
#  'IGFBP3',
#  'C7orf57',
#  'UPP1',
#  'ABCA13',
#  'EGFR',
#  'CLDN3',
#  'CLDN4',
#  'ELN',
#  'CCL24',
#  'HSPB1',
#  'CCDC146',
#  'FGL2',
#  'MAGI2-AS3',
#  'CD36',
#  'HGF',
#  'SEMA3A',
#  'KIAA1324L',
#  'STEAP4',
#  'CFAP69',
#  'CDK6',
#  'TFPI2',
#  'GNG11',
#  'COL1A2',
#  'PEG10',
#  'PDK4',
#  'AZGP1',
#  'PCOLCE',
#  'SERPINE1',
#  'UPK3BL1',
#  'AC105052.5',
#  'LRRC17',
#  'EFCAB10',
#  'CDHR3',
#  'LAMB1',
#  'IFRD1',
#  'CAV2',
#  'CAV1',
#  'MET',
#  'WNT2',
#  'CFTR',
#  'PTPRZ1',
#  'FEZF1-AS1',
#  'IQUB',
#  'HILPDA',
#  'CALU',
#  'FLNC',
#  'MEST',
#  'AUXG01000058.1',
#  'CALD1',
#  'TMEM213',
#  'CLEC5A',
#  'TRBV28',
#  'PRSS1',
#  'PRSS2',
#  'TRBC1',
#  'TRBC2',
#  'PIP',
#  'RARRES2',
#  'TMEM176B',
#  'TMEM176A',
#  'WDR86-AS1',
#  'ANGPT2',
#  'DEFB1',
#  'SOX7',
#  'CTSB',
#  'DLC1',
#  'MSR1',
#  'SLC7A2',
#  'MTUS1',
#  'SH2D4A',
#  'LPL',
#  'LGI3',
#  'SFTPC',
#  'AC105206.1',
#  'PDLIM2',
#  'PEBP4',
#  'LOXL2',
#  'NKX3-1',
#  'ADAMDEC1',
#  'CDCA2',
#  'CLU',
#  'ESCO2',
#  'PBK',
#  'SCARA5',
#  'DUSP4',
#  'NRG1',
#  'ZNF703',
#  'RAB11FIP1',
#  'FGFR1',
#  'IDO1',
#  'TCIM',
#  'SFRP1',
#  'PLAT',
#  'MCM4',
#  'EFCAB1',
#  'ALKAL1',
#  'SOX17',
#  'RP1',
#  'SDR16C5',
#  'AC022182.2',
#  'BHLHE22',
#  'SULF1',
#  'SBSPON',
#  'RDH10',
#  'AC111149.2',
#  'FABP5',
#  'FABP4',
#  'ATP6V0D2',
#  'CDH17',
#  'GEM',
#  'ESRP1',
#  'SDC2',
#  'ERICH5',
#  'RGS22',
#  'CTHRC1',
#  'ANGPT1',
#  'RSPO2',
#  'PKHD1L1',
#  'AARD',
#  'EXT1',
#  'TNFRSF11B',
#  'MAL2',
#  'COL14A1',
#  'HAS2',
#  'FAM83A',
#  'ATAD2',
#  'CASC19',
#  'MYC',
#  'LRRC6',
#  'KHDRBS3',
#  'COL22A1',
#  'ARC',
#  'PSCA',
#  'LYPD2',
#  'SLURP2',
#  'MAPK15',
#  'EPPK1',
#  'RFX3',
#  'IL33',
#  'NFIB',
#  'BNC2',
#  'TEK',
#  'AQP3',
#  'PRSS3',
#  'C9orf24',
#  'DNAI1',
#  'CCL19',
#  'CCL21',
#  'TPM2',
#  'SPAG8',
#  'BX005040.1',
#  'C9orf135',
#  'ALDH1A1',
#  'PSAT1',
#  'GAS1',
#  'CTSL',
#  'CKS2',
#  'GADD45G',
#  'IARS',
#  'OGN',
#  'OMD',
#  'ASPN',
#  'FBP1',
#  'CCDC180',
#  'HEMGN',
#  'COL15A1',
#  'BAAT',
#  'CTNNAL1',
#  'PALM2-AKAP2',
#  'TXN',
#  'SVEP1',
#  'UGCG',
#  'TNFSF15',
#  'TNC',
#  'PAPPA',
#  'MORN5',
#  'WDR38',
#  'HSPA5',
#  'ANGPTL2',
#  'CFAP157',
#  'AK1',
#  'LCN2',
#  'LRRC8A',
#  'ASS1',
#  'COL5A1',
#  'FCN1',
#  'OLFM1',
#  'C9orf116',
#  'PAEP',
#  'LCN10',
#  'LCN6',
#  'PTGDS',
#  'CLIC3',
#  'NPDC1',
#  'LRRC26',
#  'CYSRT1',
#  'TUBB4B',
#  'AKR1C1',
#  'AKR1C2',
#  'AKR1C3',
#  'IL2RA',
#  'ITIH5',
#  'SFTA1P',
#  'AL512770.1',
#  'CCDC3',
#  'ITGA8',
#  'MRC1',
#  'SPAG6',
#  'ARMC3',
#  'KIAA1217',
#  'ENKUR',
#  'ARMC4',
#  'JCAD',
#  'ZEB1',
#  'ITGB1',
#  'CXCL12',
#  'DEPP1',
#  'MSMB',
#  'GDF10',
#  'BICC1',
#  'ANK3',
#  'CDK1',
#  'CABCOCO1',
#  'ARID5B',
#  'RTKN2',
#  'STOX1',
#  'PRF1',
#  'UNC5B',
#  'UNC5B-AS1',
#  'DDIT4',
#  'CFAP70',
#  'PLAU',
#  'KCNMA1',
#  'SFTPA2',
#  'SFTPA1',
#  'SFTPD',
#  'PLAC9',
#  'DYDC2',
#  ...]

# %%
for line in gene_cell:
    print(max(line))
# Out:
# 2.1897926
# 2.1651661
# 2.7920196
# 1.5468937
# 1.1931738
# 0.0
# 2.357961
# 0.0
# 2.7372148
# 3.1248958
# 2.9193091
# 2.1014135
# 1.3594567
# 0.0
# 1.5821656
# 1.1162518
# 2.330452
# 2.822734
# 0.0
# 2.6776004
# 0.9731857
# 3.2701945
# 0.6520417
# 2.8407748
# 1.6788143
# 0.8222758
# 3.6340375
# 0.0
# 2.1570113
# 3.6965876
# 0.84676486
# 3.6703413
# 2.2040915
# 2.966108
# 3.1278186
# 4.4532127
# 2.3830287
# 5.2903624
# 0.97565055
# 0.0
# 2.0996513
# 1.095555
# 4.2244964
# 2.7202685
# 2.2531729
# 2.002366
# 7.7091126
# 1.6924223
# 3.5590467
# 0.0
# 2.9470956
# 0.0
# 4.3975067
# 1.8707706
# 1.6348754
# 1.1475731
# 0.9430844
# 0.0
# 1.9216229
# 3.596243
# 0.8845393
# 1.2267766
# 3.316125
# 0.87594736
# 3.5458758
# 2.7437682
# 2.559324
# 3.3743048
# 1.9273283
# 1.7303318
# 2.848401
# 3.8516963
# 2.3379884
# 0.0
# 2.529509
# 5.550671
# 3.1601174
# 2.8811638
# 0.0
# 3.4783754
# 0.0
# 1.9385238
# 3.360945
# 0.0
# 2.4900556
# 0.0
# 1.3366392
# 2.5709705
# 1.7380133
# 2.7242525
# 3.2835107
# 4.2497034
# 2.5608974
# 2.7242525
# 1.5098591
# 2.822734
# 3.1898735
# 1.0127478
# 1.1493376
# 0.87570214
# 4.01055
# 2.9135242
# 4.248985
# 2.0507746
# 4.8487616
# 2.5881233
# 2.609829
# 2.782014
# 0.0
# 2.740126
# 1.2529416
# 0.0
# 2.8417418
# 2.2521572
# 0.0
# 2.4246843
# 3.2477381
# 0.75412273
# 1.5530331
# 1.2001828
# 3.235705
# 4.665919
# 1.1756176
# 1.9947752
# 3.0127053
# 1.068354
# 1.4803386
# 1.360551
# 2.9801915
# 2.7807515
# 3.4557457
# 0.0
# 1.9054543
# 2.9488075
# 1.5666871
# 2.9963024
# 2.8094404
# 2.6607294
# 3.0289426
# 2.528447
# 2.9801915
# 1.1530331
# 0.8484424
# 0.97761154
# 3.5333953
# 2.6852047
# 1.7704157
# 2.698674
# 1.0223345
# 3.0725694
# 2.9582818
# 2.7749355
# 1.0419934
# 2.8986464
# 2.782014
# 2.9135242
# 3.7538464
# 2.6016295
# 1.9436849
# 2.783911
# 0.0
# 0.0
# 3.0350482
# 1.3132706
# 3.645195
# 1.6816568
# 2.3002484
# 2.7834363
# 3.840064
# 0.0
# 3.6894891
# 2.4329386
# 2.8971977
# 0.0
# 1.7925932
# 0.0
# 2.6453948
